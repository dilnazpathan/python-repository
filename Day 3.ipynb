# %% [markdown]
# ### String Slicing questions

# %%
# Question 1

s = input ("Enter a string:")
print(s[ :5 ])
# Out:
# Enter a string: dilnaz
# dilna

# %%
# Quetion 2

s = input("Enter a string")
print(s[-4: ])
# Out:
# Enter a string Dilnaz
# lnaz

# %%
# question 3

s = input("Enter a string:")
print(s[2:8])
# Out:
# Enter a string: john is studying
# hn is

# %%
# question 4

s = input("Enter a string:")
print(s[::2])
# Out:
# Enter a string: Dilnaz pathan
# Dla ahn

# %%
# question 5

name = input("Enter full name:")
space = name.index(" ")
print("First name:", name[:space])
print("Last name:",name[space+1:])
# Out:
# Enter full name: Dilnaz Rahimkha Pathan
# First name: Dilnaz
# Last name: Rahimkha Pathan

# %% [markdown]
# ### Case conversion questions

# %%
# question  6
# Uppercase
s = input("Enter a string:")
s.upper()
# Out:
# Enter a string: dilnaz
# 'DILNAZ'

# %%
# Lowercase
s = input("Enter a string:")
s.lower()
# Out:
# Enter a string: DILNAZ
# 'dilnaz'

# %%
# Titlecase
s = input("Enter a string: ")
s.title()
# Out:
# Enter a string:  john
# 'John'

# %%
#Capitalized
s = input("Enter a string: ")
s.capitalize()
# Out:
# Enter a string:  john
# 'John'

# %%
#question 7
s = input("Enter a sentence:")
print("original: ",s)
print("Title:", s.title())
# Out:
# Enter a sentence: sam is doing work
# original:  sam is doing work
# Title: Sam Is Doing Work

# %%
# question 8
s = input("Enter a mixed string:")
print("Lower: ",s.lower())
print("Upper:",s.upper())
# Out:
# Enter a mixed string: JoHn Is running
# Lower:  john is running
# Upper: JOHN IS RUNNING

# %%
# question 9

s = input("Enter a string: ")
s.isalpha()
# Out:
# Enter a string:  dilnaz
# True

# %%
# question 10

s = input("Enter a value: ")
s.isdigit()
# Out:
# Enter a value:  987966
# True

# %%
# question 11

s = input("Enter a sentence:")
s.isalnum()
# Out:
# Enter a sentence: dilnaz123
# True

# %%
# question 12

s = input("Enter a sentence:")
s.islower()
# Out:
# Enter a sentence: dilnaz
# True

# %%
# question 13

password = input("Enter a password:")
print("Valid password" if password.isalnum() and len(password) >= 8 else "invalid password")
# Out:
# Enter a password: hywd455325
# Valid password

# %% [markdown]
# ### find() and index() questions

# %%
# question 14

s = input ("Enter a string:")
c = input("Enter a character:")
s.find(c)
# Out:
# Enter a string: python is easy
# Enter a character: easy
# 10

# %%
# question 15

string =input ("Enter a string:")
word = input("Enter a word:")
string.find(word)
# Out:
# Enter a string: bob is doing his work
# Enter a word: work
# 17

# %%
# question 16

s = input("Enter the sentence:")
print("Position:", s.index("Python"))
# Out:
# Enter the sentence: programming language Python is good
# Position: 21

# %%
# question 17

string = input("Enter a string:")
character = input("Enter a character:")
print("Using find():",string.find(character))
print("Using index():",string.index(character))
# Out:
# Enter a string: java
# Enter a character: v
# Using find(): 2
# Using index(): 2

# %% [markdown]
# ### Mixed questions

# %%
# question 18

name = input("Enter your full name:")
name.upper()
space_pos = name.find(" ")
print("First space position:", space_pos)
print("First name:", name[:space_pos])
print("Last name:", name[space_pos + 1:])
# Out:
# Enter your full name: dilnaz rahimkha pathan
# First space position: 6
# First name: dilnaz
# Last name: rahimkha pathan

# %%
# question 19

num = (input("Enter mobile number:"))
num.isdigit()
len(num) == 10
# Out:
# Enter mobile number: 9798775643
# True

# %%
# question 20

s = input("Enter a string:")
reverse = s[::-1]
print("Reverse s:",reverse)
s.title()
# Out:
# Enter a string: python
# Reverse s: nohtyp
# 'Python'
