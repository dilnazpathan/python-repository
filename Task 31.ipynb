# %% [markdown]
# ### Pandas Challenges (Based on Your Notebook)

# %%
# Challenge 1 – Complete Data Cleaning
#Your manager gives you a messy dataset.
#Perform all of the following:
#• Load the dataset.
#• Display dataset information.
#• Find missing values.
#• Remove duplicate rows.
#• Fill missing values:
#o Age → median
#o Balance → mean
#• Rename:
#o Target → CustomerStatus
#o AnnualIncome → Income
#• Display the first 15 rows.
#Methods expected:
#read_csv()
#info()
#isnull()
#drop_duplicates()
#median()
#mean()
#fillna()
#rename()
#head()

import pandas as pd

df2 = pd.read_csv("C:\\Users\\DELL\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df2.isnull().sum()
# Out:
# CustomerID       0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df2.drop_duplicates()
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
# ...

# %%
df2["Age"]=df2["Age"].fillna(df2["Age"].median())
df2.head(10)
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001  58.0       49184.0      2139          581   97523.535666
# 1       10002  65.0      162964.0      6197          732    6356.540000
# 2       10003  56.0       26956.0     37281          503  143203.920000
# 3       10004  55.0       92926.0       925          463  139627.880000
# 4       10005  66.0      108236.0      7198          394   75985.460000
# 5       10006  69.0       31390.0     48323          770  107245.620000
# 6       10007  58.0      182141.0     24200          891   38457.720000
# 7       10008  67.0       95861.0      5729          538  173296.730000
# 8       10009  41.0       62638.0     24760          663   41901.410000
# 9       10010  22.0      179680.0     42113          475  106827.980000
#
#    Tenure Geography  Gender    Segment Target
# 0       2    France    Male        SME   Stay
# 1       1       USA    Male        SME  Churn
# ...

# %%
df2["Balance"]=df2["Balance"].fillna(df2["Balance"].mean())
df2.head(15)
# Out:
#     CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0        10001  58.0       49184.0      2139          581   97523.535666
# 1        10002  65.0      162964.0      6197          732    6356.540000
# 2        10003  56.0       26956.0     37281          503  143203.920000
# 3        10004  55.0       92926.0       925          463  139627.880000
# 4        10005  66.0      108236.0      7198          394   75985.460000
# 5        10006  69.0       31390.0     48323          770  107245.620000
# 6        10007  58.0      182141.0     24200          891   38457.720000
# 7        10008  67.0       95861.0      5729          538  173296.730000
# 8        10009  41.0       62638.0     24760          663   41901.410000
# 9        10010  22.0      179680.0     42113          475  106827.980000
# 10       10011  44.0      187772.0     45599          870   43923.030000
# 11       10012  69.0      102694.0     26790          574   13237.720000
# ...

# %%
# Reaname
df2 = df2.rename(columns={"Target":"CustomerStatus","AnnualIncome":"Income"})
df2
# Out:
#       CustomerID   Age    Income  Spending  CreditScore        Balance  \
# 0          10001  58.0   49184.0      2139          581   97523.535666
# 1          10002  65.0  162964.0      6197          732    6356.540000
# 2          10003  56.0   26956.0     37281          503  143203.920000
# 3          10004  55.0   92926.0       925          463  139627.880000
# 4          10005  66.0  108236.0      7198          394   75985.460000
# ...          ...   ...       ...       ...          ...            ...
# 1015       10450  43.0  173620.0      7121          644   60353.030000
# 1016       10753  25.0   54490.0     13794          303  124512.070000
# 1017       10810  49.0   82062.0     47170          813   53850.090000
# 1018       10267  38.0       NaN     10424          722  138100.050000
# 1019       10059  62.0   97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment CustomerStatus
# 0          2    France    Male        SME           Stay
# ...

# %%
 df2.head(15)
# Out:
#     CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 0        10001  58.0   49184.0      2139          581   97523.535666       2
# 1        10002  65.0  162964.0      6197          732    6356.540000       1
# 2        10003  56.0   26956.0     37281          503  143203.920000       8
# 3        10004  55.0   92926.0       925          463  139627.880000       5
# 4        10005  66.0  108236.0      7198          394   75985.460000       5
# 5        10006  69.0   31390.0     48323          770  107245.620000       6
# 6        10007  58.0  182141.0     24200          891   38457.720000       1
# 7        10008  67.0   95861.0      5729          538  173296.730000       6
# 8        10009  41.0   62638.0     24760          663   41901.410000       4
# 9        10010  22.0  179680.0     42113          475  106827.980000       3
# 10       10011  44.0  187772.0     45599          870   43923.030000       5
# ...

# %%
# Challenge 2 – Banking Report
#The bank wants a numeric report.
#Tasks
#• Select only numeric columns.
#• Display summary statistics.
#• Convert Age and CreditScore to float.
#• Display information again.

df2.select_dtypes(include="number")
# Out:
#       CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure
# 0          10001  58.0   49184.0      2139          581   97523.535666       2
# 1          10002  65.0  162964.0      6197          732    6356.540000       1
# 2          10003  56.0   26956.0     37281          503  143203.920000       8
# 3          10004  55.0   92926.0       925          463  139627.880000       5
# 4          10005  66.0  108236.0      7198          394   75985.460000       5
# ...          ...   ...       ...       ...          ...            ...     ...
# 1015       10450  43.0  173620.0      7121          644   60353.030000       2
# 1016       10753  25.0   54490.0     13794          303  124512.070000       4
# 1017       10810  49.0   82062.0     47170          813   53850.090000       8
# 1018       10267  38.0       NaN     10424          722  138100.050000       6
# 1019       10059  62.0   97504.0     36833          430   97523.535666      10
#
# [1020 rows x 7 columns]

# %%
df2.describe()
# Out:
#          CustomerID          Age         Income      Spending  CreditScore  \
# count   1020.000000  1020.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112505.928645  25232.615686   602.659804
# std      288.022115    15.136428   52303.362541  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   66149.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  158000.500000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# ...

# %%
df2["Age"] = df2["Age"].astype(float)
df2["CreditScore"]= df2["CreditScore"].astype(float)
df2
# Out:
#       CustomerID   Age    Income  Spending  CreditScore        Balance  \
# 0          10001  58.0   49184.0      2139        581.0   97523.535666
# 1          10002  65.0  162964.0      6197        732.0    6356.540000
# 2          10003  56.0   26956.0     37281        503.0  143203.920000
# 3          10004  55.0   92926.0       925        463.0  139627.880000
# 4          10005  66.0  108236.0      7198        394.0   75985.460000
# ...          ...   ...       ...       ...          ...            ...
# 1015       10450  43.0  173620.0      7121        644.0   60353.030000
# 1016       10753  25.0   54490.0     13794        303.0  124512.070000
# 1017       10810  49.0   82062.0     47170        813.0   53850.090000
# 1018       10267  38.0       NaN     10424        722.0  138100.050000
# 1019       10059  62.0   97504.0     36833        430.0   97523.535666
#
#       Tenure Geography  Gender    Segment CustomerStatus
# 0          2    France    Male        SME           Stay
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1020 non-null   int64
#  1   Age             1020 non-null   float64
#  2   Income          967 non-null    float64
#  3   Spending        1020 non-null   int64
#  4   CreditScore     1020 non-null   float64
#  5   Balance         1020 non-null   float64
#  6   Tenure          1020 non-null   int64
#  7   Geography       969 non-null    object
#  8   Gender          968 non-null    object
#  9   Segment         969 non-null    object
#  10  CustomerStatus  1020 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 87.8+ KB

# %%
# Challenge 3 – Duplicate Investigation
#Find duplicate customers.
#Then
#• Count duplicate rows.
#• Remove duplicates.
#• Print information before and after removing duplicates.
#• Show the last 20 rows.

df2.duplicated().sum()
# Out:
# np.int64(20)

# %%
df2.drop_duplicates()
# Out:
#      CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 0         10001  58.0   49184.0      2139        581.0   97523.535666       2
# 1         10002  65.0  162964.0      6197        732.0    6356.540000       1
# 2         10003  56.0   26956.0     37281        503.0  143203.920000       8
# 3         10004  55.0   92926.0       925        463.0  139627.880000       5
# 4         10005  66.0  108236.0      7198        394.0   75985.460000       5
# ..          ...   ...       ...       ...          ...            ...     ...
# 995       10996  34.0   81731.0     40980        761.0  181465.650000       5
# 996       10997  47.0   42475.0      1176        780.0   26640.990000       5
# 997       10998  31.0  120531.0     46929        733.0  147220.820000       4
# 998       10999  21.0   33661.0     22314        540.0   94186.480000       5
# 999       11000  63.0   31930.0       851        559.0  100908.400000       6
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1020 non-null   int64
#  1   Age             1020 non-null   float64
#  2   Income          967 non-null    float64
#  3   Spending        1020 non-null   int64
#  4   CreditScore     1020 non-null   float64
#  5   Balance         1020 non-null   float64
#  6   Tenure          1020 non-null   int64
#  7   Geography       969 non-null    object
#  8   Gender          968 non-null    object
#  9   Segment         969 non-null    object
#  10  CustomerStatus  1020 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 87.8+ KB

# %%
df2.tail(20)
# Out:
#       CustomerID   Age    Income  Spending  CreditScore        Balance  \
# 1000       10643  41.0  125012.0     18825        761.0   35977.850000
# 1001       10763  56.0  102965.0     17517        838.0  115028.540000
# 1002       10910  66.0  118506.0      6296        306.0   81892.130000
# 1003       10200  19.0  115052.0     20741        484.0  190233.860000
# 1004       10587  29.0       NaN     40255        383.0  168358.600000
# 1005       10798  22.0  176830.0      7626        688.0   65481.650000
# 1006       10653  32.0       NaN     21266        598.0  142086.700000
# 1007       10756  53.0   74430.0      3705        489.0   29651.230000
# 1008       10417  70.0   40417.0     37956        681.0   23880.190000
# 1009       10499  34.0  166546.0     12497        643.0  130886.930000
# 1010       10515  62.0  199762.0     41808        309.0   60223.290000
# 1011       10457  44.0   63604.0     27633        804.0  176354.130000
# ...

# %%
# Challenge 4 – HR Department
#HR wants better column names.
#Rename
#CustomerID → Employee_ID
#Age → EmployeeAge
#Gender → EmployeeGender
#AnnualIncome → Salary
#Target → PromotionStatus
#Then
#• Add prefix
#HR_
#to every column.
#Display 10 random records.

df2.rename(columns={"Age":"Employee_ID","AnnualIncome":"Salary","Target":"PromotionStatus"})
# Out:
#       CustomerID  Employee_ID    Income  Spending  CreditScore        Balance  \
# 0          10001         58.0   49184.0      2139        581.0   97523.535666
# 1          10002         65.0  162964.0      6197        732.0    6356.540000
# 2          10003         56.0   26956.0     37281        503.0  143203.920000
# 3          10004         55.0   92926.0       925        463.0  139627.880000
# 4          10005         66.0  108236.0      7198        394.0   75985.460000
# ...          ...          ...       ...       ...          ...            ...
# 1015       10450         43.0  173620.0      7121        644.0   60353.030000
# 1016       10753         25.0   54490.0     13794        303.0  124512.070000
# 1017       10810         49.0   82062.0     47170        813.0   53850.090000
# 1018       10267         38.0       NaN     10424        722.0  138100.050000
# 1019       10059         62.0   97504.0     36833        430.0   97523.535666
#
# ...

# %%
df2.add_prefix("HR_")
# Out:
#       HR_CustomerID  HR_Age  HR_Income  HR_Spending  HR_CreditScore  \
# 0             10001    58.0    49184.0         2139           581.0
# 1             10002    65.0   162964.0         6197           732.0
# 2             10003    56.0    26956.0        37281           503.0
# 3             10004    55.0    92926.0          925           463.0
# 4             10005    66.0   108236.0         7198           394.0
# ...             ...     ...        ...          ...             ...
# 1015          10450    43.0   173620.0         7121           644.0
# 1016          10753    25.0    54490.0        13794           303.0
# 1017          10810    49.0    82062.0        47170           813.0
# 1018          10267    38.0        NaN        10424           722.0
# 1019          10059    62.0    97504.0        36833           430.0
#
#          HR_Balance  HR_Tenure HR_Geography HR_Gender HR_Segment  \
# 0      97523.535666          2       France      Male        SME
# ...

# %%
df2.sample(10)
# Out:
#       CustomerID   Age    Income  Spending  CreditScore    Balance  Tenure  \
# 358        10359  27.0  110431.0      2109        794.0   20909.87       6
# 453        10454  58.0       NaN      7322        808.0   28128.67       1
# 1015       10450  43.0  173620.0      7121        644.0   60353.03       2
# 896        10897  46.0   88264.0     24726        488.0   41031.07       0
# 439        10440  58.0  162516.0      1779        691.0  156383.15       5
# 38         10039  26.0  196079.0     42803        607.0   91444.91       1
# 370        10371  52.0  189151.0     11853        868.0   33373.10       4
# 128        10129  43.0  190350.0      5763        636.0  170468.27       8
# 81         10082  31.0  141905.0     46340        562.0  153379.62       2
# 693        10694  70.0  181725.0     17920        841.0    8130.63       1
#
#      Geography  Gender    Segment CustomerStatus
# 358      India    Male        SME           Stay
# ...

# %%
# Challenge 5 – Finance Cleaning
#Finance department reports missing values.
#Tasks
#Fill
#AnnualIncome → Median
#Balance → Mean
#Age → Median
#Then
#Generate descriptive statistics.

df2 = pd.read_csv("C:\\Users\\DELL\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
df2["AnnualIncome"] = df2["AnnualIncome"].fillna(df2["AnnualIncome"].median())

# %%
df2["Balance"] = df2["Balance"].fillna(df2["Balance"].mean())

# %%
df2["Age"] = df2["Age"].fillna(df2["Age"].median())

# %%
df2.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# ...

# %%
# Challenge 6 – Data Type Audit
#The company says
#Age and AnnualIncome are stored incorrectly.
#Tasks
#Convert
#Age → int
#AnnualIncome → float
#Balance → float
#Target → string
#Print information.

df2["Age"] = df2["Age"].astype(int)
df2["AnnualIncome"]=df2["AnnualIncome"].astype(float)
df2["Balance"]=df2["Balance"].astype(float)
df2["Target"]=df2["Target"].astype(str)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 87.8+ KB

# %%
# Challenge 7 – Customer Analytics
#Create a new DataFrame that
#• removes Segment
#• removes Geography
#• removes duplicate rows
#Display
#• first 10 rows
#• dataset information
#• statistical summary

df2_new = df2.drop(columns=["Segment","Geography"])
df2_new.drop_duplicates()
df2.head(10)
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001   58       49184.0      2139          581   97523.535666
# 1       10002   65      162964.0      6197          732    6356.540000
# 2       10003   56       26956.0     37281          503  143203.920000
# 3       10004   55       92926.0       925          463  139627.880000
# 4       10005   66      108236.0      7198          394   75985.460000
# 5       10006   69       31390.0     48323          770  107245.620000
# 6       10007   58      182141.0     24200          891   38457.720000
# 7       10008   67       95861.0      5729          538  173296.730000
# 8       10009   41       62638.0     24760          663   41901.410000
# 9       10010   22      179680.0     42113          475  106827.980000
#
#    Tenure Geography  Gender    Segment Target
# 0       2    France    Male        SME   Stay
# 1       1       USA    Male        SME  Churn
# 2       8    Canada    Male  Corporate   Stay
# ...

# %%
df2_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Gender        968 non-null    object
#  8   Target        1020 non-null   object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 71.8+ KB

# %%
df2_new.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# ...

# %%
# Challenge 8 – ML Dataset Preparation
#Prepare a machine learning dataset.
#Perform
#• Remove duplicates
#• Remove CustomerID
#• Remove Segment
#• Fill missing values
#• Rename Target to Output
#Finally
#Display
#head()
#info()
#describe()
#value_counts(Output)

df2.drop_duplicates()
df2.drop(columns=["CustomerID","Segment"])
df2["Age"] = df2["Age"].fillna(df2["Age"].median())
df2["Balance"]=df2["Balance"].fillna(df2["Balance"].median())
df2["AnnialIncome"] = df2["AnnualIncome"].fillna(df2["AnnualIncome"].mean())
df2_n=df2.rename(columns={"Target":"Output"})
df2_n.head()
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001   58       49184.0      2139          581   97523.535666
# 1       10002   65      162964.0      6197          732    6356.540000
# 2       10003   56       26956.0     37281          503  143203.920000
# 3       10004   55       92926.0       925          463  139627.880000
# 4       10005   66      108236.0      7198          394   75985.460000
#
#    Tenure Geography Gender    Segment Output  AnnialIncome
# 0       2    France   Male        SME   Stay       49184.0
# 1       1       USA   Male        SME  Churn      162964.0
# 2       8    Canada   Male  Corporate   Stay       26956.0
# 3       5       NaN   Male     Retail  Churn       92926.0
# 4       5        UK  Other  Corporate  Churn      108236.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
#  11  AnnialIncome  1020 non-null   float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 95.8+ KB

# %%
df2.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure   AnnialIncome
# count    1020.000000  1020.000000    1020.000000
# mean    97523.535666     5.261765  112498.242157
# std     54382.357541     3.185330   50925.015723
# min       547.600000     0.000000   20227.000000
# ...

# %%
df2_n["Output"].value_counts()
# Out:
# Output
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
# Challenge 9 – Column Transformation
#Create these new columns
#NetWorth = Balance + AnnualIncome
#AgeAfterRetirement = Age + 20
#DoubleCreditScore = CreditScore * 2
#IncomePerMonth = AnnualIncome / 12
#Then
#Display first 15 rows.

df2["NetWorth"]=df2["Balance"]+df2["AnnualIncome"]
df2["AgeAfterRetirement"]=df2["Age"]+20
df2["DoubleCreditScore"]=df2["CreditScore"]*2
df2["IncomePerMonth"]=df2["AnnualIncome"]/12
df2.head(15)
# Out:
#     CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0        10001   58       49184.0      2139          581   97523.535666
# 1        10002   65      162964.0      6197          732    6356.540000
# 2        10003   56       26956.0     37281          503  143203.920000
# 3        10004   55       92926.0       925          463  139627.880000
# 4        10005   66      108236.0      7198          394   75985.460000
# 5        10006   69       31390.0     48323          770  107245.620000
# 6        10007   58      182141.0     24200          891   38457.720000
# 7        10008   67       95861.0      5729          538  173296.730000
# 8        10009   41       62638.0     24760          663   41901.410000
# 9        10010   22      179680.0     42113          475  106827.980000
# 10       10011   44      187772.0     45599          870   43923.030000
# 11       10012   69      102694.0     26790          574   13237.720000
# ...

# %%
# Challenge 10 – Company Report
#Display
#• first five rows
#• last five rows
#• ten random rows
#• dataset information
#• descriptive statistics
#Finally rename
#Target → Customer_Status

df2.head()
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001   58       49184.0      2139          581   97523.535666
# 1       10002   65      162964.0      6197          732    6356.540000
# 2       10003   56       26956.0     37281          503  143203.920000
# 3       10004   55       92926.0       925          463  139627.880000
# 4       10005   66      108236.0      7198          394   75985.460000
#
#    Tenure Geography Gender    Segment Target  AnnialIncome       NetWorth  \
# 0       2    France   Male        SME   Stay       49184.0  146707.535666
# 1       1       USA   Male        SME  Churn      162964.0  169320.540000
# 2       8    Canada   Male  Corporate   Stay       26956.0  170159.920000
# 3       5       NaN   Male     Retail  Churn       92926.0  232553.880000
# 4       5        UK  Other  Corporate  Churn      108236.0  184221.460000
#
#    AgeAfterRetirement  DoubleCreditScore  IncomePerMonth
# ...

# %%
df2.tail()
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 1015       10450   43      173620.0      7121          644   60353.030000
# 1016       10753   25       54490.0     13794          303  124512.070000
# 1017       10810   49       82062.0     47170          813   53850.090000
# 1018       10267   38      112358.0     10424          722  138100.050000
# 1019       10059   62       97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment Target  AnnialIncome       NetWorth  \
# 1015       2       USA   Other  Corporate   Stay      173620.0  233973.030000
# 1016       4     India     NaN  Corporate  Churn       54490.0  179002.070000
# 1017       8   Germany  Female     Retail   Stay       82062.0  135912.090000
# 1018       6   Germany   Other  Corporate   Stay      112358.0  250458.050000
# 1019      10    Canada   Other        NaN  Churn       97504.0  195027.535666
#
# ...

# %%
df2.sample(10)
# Out:
#      CustomerID  Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 746       10747   25       67125.0     38867          859   27061.33       6
# 566       10567   51      118293.0     34205          820   89111.38       0
# 252       10253   28      105835.0     38359          620   37966.82       2
# 248       10249   43       97970.0     30223          374  137722.71       2
# 701       10702   56       24273.0     34422          438  198682.40       4
# 863       10864   69      138789.0      3338          406  148083.38       8
# 590       10591   47      112358.0     33950          392   79357.03       8
# 142       10143   68      112358.0     24476          843  100358.95       4
# 964       10965   29       24876.0     41646          828  172541.96       9
# 36        10037   54       84543.0     38440          340  123876.30       6
#
#     Geography  Gender    Segment Target  AnnialIncome   NetWorth  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          1020 non-null   int64
#  1   Age                 1020 non-null   int64
#  2   AnnualIncome        1020 non-null   float64
#  3   Spending            1020 non-null   int64
#  4   CreditScore         1020 non-null   int64
#  5   Balance             1020 non-null   float64
#  6   Tenure              1020 non-null   int64
#  7   Geography           969 non-null    object
#  8   Gender              968 non-null    object
#  9   Segment             969 non-null    object
#  10  Target              1020 non-null   object
#  11  AnnialIncome        1020 non-null   float64
#  12  NetWorth            1020 non-null   float64
#  13  AgeAfterRetirement  1020 non-null   int64
#  14  DoubleCreditScore   1020 non-null   int64
# ...

# %%
df2.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure   AnnialIncome       NetWorth  \
# count    1020.000000  1020.000000    1020.000000    1020.000000
# mean    97523.535666     5.261765  112498.242157  210021.777822
# std     54382.357541     3.185330   50925.015723   72924.053575
# ...

# %%
df2.rename(columns={"Target":"Customer_Status"})
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001   58       49184.0      2139          581   97523.535666
# 1          10002   65      162964.0      6197          732    6356.540000
# 2          10003   56       26956.0     37281          503  143203.920000
# 3          10004   55       92926.0       925          463  139627.880000
# 4          10005   66      108236.0      7198          394   75985.460000
# ...          ...  ...           ...       ...          ...            ...
# 1015       10450   43      173620.0      7121          644   60353.030000
# 1016       10753   25       54490.0     13794          303  124512.070000
# 1017       10810   49       82062.0     47170          813   53850.090000
# 1018       10267   38      112358.0     10424          722  138100.050000
# 1019       10059   62       97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment Customer_Status  AnnialIncome  \
# ...

# %%
# Challenge 11 – Missing Value Report
#Create a report showing
#• Total missing values
#• Numerical columns
#• Mean of Balance
#• Median of Age
#• Fill missing values
#• Display information again

df2.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# AnnualIncome           0
# Spending               0
# CreditScore            0
# Balance                0
# Tenure                 0
# Geography             51
# Gender                52
# Segment               51
# Target                 0
# AnnialIncome           0
# NetWorth               0
# AgeAfterRetirement     0
# DoubleCreditScore      0
# IncomePerMonth         0
# dtype: int64

# %%
df2.select_dtypes(include="number").columns
# Out:
# Index(['CustomerID', 'Age', 'AnnualIncome', 'Spending', 'CreditScore',
#        'Balance', 'Tenure', 'AnnialIncome', 'NetWorth', 'AgeAfterRetirement',
#        'DoubleCreditScore', 'IncomePerMonth'],
#       dtype='object')

# %%
df2["Balance"].mean()
# Out:
# np.float64(97523.53566563467)

# %%
df2["Age"].median()
# Out:
# 44.0

# %%
df2["AnnualIncome"].fillna(df2["AnnualIncome"].median())
df2["Balance"].fillna(df2["Balance"].mean())
df2["Age"].fillna(df2["Age"].median())
# Out:
# 0       58
# 1       65
# 2       56
# 3       55
# 4       66
#         ..
# 1015    43
# 1016    25
# 1017    49
# 1018    38
# 1019    62
# Name: Age, Length: 1020, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          1020 non-null   int64
#  1   Age                 1020 non-null   int64
#  2   AnnualIncome        1020 non-null   float64
#  3   Spending            1020 non-null   int64
#  4   CreditScore         1020 non-null   int64
#  5   Balance             1020 non-null   float64
#  6   Tenure              1020 non-null   int64
#  7   Geography           969 non-null    object
#  8   Gender              968 non-null    object
#  9   Segment             969 non-null    object
#  10  Target              1020 non-null   object
#  11  AnnialIncome        1020 non-null   float64
#  12  NetWorth            1020 non-null   float64
#  13  AgeAfterRetirement  1020 non-null   int64
#  14  DoubleCreditScore   1020 non-null   int64
# ...

# %%
# Challenge 12 – Customer Classification
#Count
#Stay
#Churn
#Then
#Rename
#Target → Customer_Class
#Convert it into string.

df2["Target"].value_counts()
# Out:
# Target
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
df2=df2.rename(columns={"Target":"Customer_Class"})
df2
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001   58       49184.0      2139          581   97523.535666
# 1          10002   65      162964.0      6197          732    6356.540000
# 2          10003   56       26956.0     37281          503  143203.920000
# 3          10004   55       92926.0       925          463  139627.880000
# 4          10005   66      108236.0      7198          394   75985.460000
# ...          ...  ...           ...       ...          ...            ...
# 1015       10450   43      173620.0      7121          644   60353.030000
# 1016       10753   25       54490.0     13794          303  124512.070000
# 1017       10810   49       82062.0     47170          813   53850.090000
# 1018       10267   38      112358.0     10424          722  138100.050000
# 1019       10059   62       97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment Customer_Class  AnnialIncome  \
# ...

# %%
df2["Customer_Class"]=df2["Customer_Class"].astype(str)
df2
# Out:
#       CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001   58       49184.0      2139          581   97523.535666
# 1          10002   65      162964.0      6197          732    6356.540000
# 2          10003   56       26956.0     37281          503  143203.920000
# 3          10004   55       92926.0       925          463  139627.880000
# 4          10005   66      108236.0      7198          394   75985.460000
# ...          ...  ...           ...       ...          ...            ...
# 1015       10450   43      173620.0      7121          644   60353.030000
# 1016       10753   25       54490.0     13794          303  124512.070000
# 1017       10810   49       82062.0     47170          813   53850.090000
# 1018       10267   38      112358.0     10424          722  138100.050000
# 1019       10059   62       97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment Customer_Class  AnnialIncome  \
# ...

# %%
# Challenge 13 – Sales Department
#Rename
#Balance → AccountBalance
#AnnualIncome → Salary
#CreditScore → Score
#Add prefix
#Sales_
#Then
#Display
#sample(20)

df2=df2.rename(columns={"Balance":"AccountBalance","AnnualIncome":"Salary",
                    "CreditScore":"Score"})
df2=df2.add_prefix("Sales_")
df2.sample(20)
# Out:
#      Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 908             10909         44       57654.0           14117          610
# 409             10410         18       55969.0           46473          311
# 817             10818         68       92836.0           17018          435
# 123             10124         46      112358.0           32241          653
# 439             10440         58      162516.0            1779          691
# 655             10656         24       45048.0            4680          784
# 761             10762         54      184882.0           35165          389
# 180             10181         50      166466.0           44281          662
# 12              10013         59      150870.0           26428          769
# 231             10232         61      137944.0           24811          680
# 268             10269         51      118782.0           21062          477
# ...

# %%
# Challenge 14 – Interview Challenge
#Without creating another DataFrame,
#perform
#• remove duplicates
#• rename Target
#• fill missing values
#• convert Balance to float
#• display summary

df2 = pd.read_csv("C:\\Users\\DELL\\Downloads\\Task_dataset - Task_dataset.csv")
df2.drop_duplicates(inplace=True)
df2.rename(columns={"Target":"Customer_Status"},inplace=True)
df2["Age"].fillna(df2["Age"].median(), inplace=True)
df2["AnnualIncome"].fillna(df2["AnnualIncome"].median(), inplace=True)
df2["Balance"].fillna(df2["Balance"].mean(), inplace=True)
df2["Balance"]=df2["Balance"].astype(float)
df2.describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15408\2952940832.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["Age"].fillna(df2["Age"].median(), inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15408\2952940832.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Challenge 15 – Data Engineer Task
#Load the dataset.
#Create another DataFrame containing only numeric columns.
#Drop
#CustomerID
#Target
#Display summary.

import pandas as pd
df2 = pd.read_csv("C:\\Users\\DELL\\Downloads\\Task_dataset - Task_dataset.csv")
df3 = df2.select_dtypes(include="number")
df3.drop(columns=["CustomerID"],inplace=True)
df3.describe()
# Out:
#               Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  970.000000     967.000000   1020.000000  1020.000000     969.000000
# mean    44.249485  112505.928645  25232.615686   602.659804   97523.535666
# std     15.521935   52303.362541  14219.393105   176.560690   55796.562543
# min     18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%     30.250000   66149.000000  13134.750000   440.750000   50077.860000
# 50%     44.000000  112358.000000  24798.000000   607.000000   95100.060000
# 75%     58.000000  158000.500000  37956.000000   757.250000  143947.810000
# max     70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
#             Tenure
# count  1020.000000
# mean      5.261765
# std       3.185330
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000

# %%
# Challenge 16 – Mixed Cleaning
#Perform
#drop_duplicates()
#fillna()
#astype()
#rename()
#head()
#info()
#using only one DataFrame variable.

df2.drop_duplicates(inplace=True)
df2["Age"]=df2["Age"].fillna(df2["Age"].median())
df2["AnnualIncome"]=df2["AnnualIncome"].fillna(df2["AnnualIncome"].median())
df2["Balance"]=df2["Balance"].fillna(df2["Balance"].mean())
df2["Balance"]=df2["Balance"].astype(float)
df2.rename(columns={"Target":"Customer_Status"},inplace=True)
df2.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001  58.0       49184.0      2139          581   97557.565779
# 1       10002  65.0      162964.0      6197          732    6356.540000
# 2       10003  56.0       26956.0     37281          503  143203.920000
# 3       10004  55.0       92926.0       925          463  139627.880000
# 4       10005  66.0      108236.0      7198          394   75985.460000
#
#    Tenure Geography Gender    Segment Customer_Status
# 0       2    France   Male        SME            Stay
# 1       1       USA   Male        SME           Churn
# 2       8    Canada   Male  Corporate            Stay
# 3       5       NaN   Male     Retail           Churn
# 4       5        UK  Other  Corporate           Churn

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   int64
#  1   Age              1000 non-null   float64
#  2   AnnualIncome     1000 non-null   float64
#  3   Spending         1000 non-null   int64
#  4   CreditScore      1000 non-null   int64
#  5   Balance          1000 non-null   float64
#  6   Tenure           1000 non-null   int64
#  7   Geography        950 non-null    object
#  8   Gender           950 non-null    object
#  9   Segment          950 non-null    object
#  10  Customer_Status  1000 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
# Challenge 17 – Real Company Dataset
#Manager asks
#Remove duplicate records
#Fill missing values
#Rename all business columns
#Add company prefix
#Display summary
#Display target counts

df2.drop_duplicates(inplace=True)
df2["Age"] = df2["Age"].fillna(df2["Age"].median())
df2["AnnualIncome"] = df2["AnnualIncome"].fillna(df2["AnnualIncome"].median())
df2["Balance"] = df2["Balance"].fillna(df2["Balance"].mean())
df2.rename(columns={"CustomerID": "Employee_ID","Age": "Employee_Age","Gender": "Employee_Gender",
    "AnnualIncome": "Salary","Target": "Customer_Status"}, inplace=True)
df2 = df2.add_prefix("Company_")
df2.describe()
# Out:
#        Company_Employee_ID  Company_Employee_Age  Company_Salary  \
# count          1000.000000           1000.000000     1000.000000
# mean          10500.500000             44.202000   112452.763000
# std             288.819436             15.130834    51081.480963
# min           10001.000000             18.000000    20227.000000
# 25%           10250.750000             31.000000    68437.250000
# 50%           10500.500000             44.000000   112347.500000
# 75%           10750.250000             57.000000   155570.750000
# max           11000.000000             70.000000   199967.000000
#
#        Company_Spending  Company_CreditScore  Company_Balance  Company_Tenure
# count       1000.000000          1000.000000      1000.000000     1000.000000
# mean       25285.558000           603.088000     97557.565779        5.241000
# std        14211.735656           176.605486     54430.062006        3.179155
# ...

# %%
df2["Company_Customer_Status"].value_counts()
# Out:
# Company_Customer_Status
# Churn    506
# Stay     494
# Name: count, dtype: int64

# %%
# Challenge 18 – Customer Summary
#Generate
#Mean Balance
#Median Balance
#Mean Age
#Median AnnualIncome
#Then
#fill missing values using these statistics.

import pandas as pd
df2 = pd.read_csv(r"C:\Users\DELL\Downloads\Task_dataset - Task_dataset.csv")
print("Mean Balance:", df2["Balance"].mean())
print("Median Balance:",df2["Balance"].median())
print("Median AnnualIncome:",df2["AnnualIncome"].median())
df2["Balance"] = df2["Balance"].fillna(df2["Balance"].mean())
df2["Age"] = df2["Age"].fillna(df2["Age"].mean())
df2["AnnualIncome"] = df2["AnnualIncome"].fillna(df2["AnnualIncome"].median())
df2.info()
# Out:
# Mean Balance: 97523.53566563467
# Median Balance: 95100.06
# Median AnnualIncome: 112358.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   float64
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
# Challenge 19 – Transformation Challenge
#Create
#Income_in_Lakhs
#Balance_in_Lakhs
#SeniorCitizen
#HighCreditScore
#where
#SeniorCitizen = Age + 0
#HighCreditScore = CreditScore * 1
#(No conditional statements.)

df2["Income_in_Lakhs"] = df2["AnnualIncome"]/100000
df2["Balance_in_Lakhs"]=df2["Balance"]/100000
df2["SeniorCitizen"]=df2["Age"]+0
df2["HighCreditScore"]=df2["CreditScore"]*1
df2.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001  58.0       49184.0      2139          581   97523.535666
# 1       10002  65.0      162964.0      6197          732    6356.540000
# 2       10003  56.0       26956.0     37281          503  143203.920000
# 3       10004  55.0       92926.0       925          463  139627.880000
# 4       10005  66.0      108236.0      7198          394   75985.460000
#
#    Tenure Geography Gender    Segment Target  Income_in_Lakhs  \
# 0       2    France   Male        SME   Stay          0.49184
# 1       1       USA   Male        SME  Churn          1.62964
# 2       8    Canada   Male  Corporate   Stay          0.26956
# 3       5       NaN   Male     Retail  Churn          0.92926
# 4       5        UK  Other  Corporate  Churn          1.08236
#
#    Balance_in_Lakhs  SeniorCitizen  HighCreditScore
# 0          0.975235           58.0              581
# 1          0.063565           65.0              732
# ...

# %%
# Challenge 20 – Final Interview Project
#Your manager gives you a dirty customer dataset.
#Prepare the final dataset.
#Requirements
#Load dataset
#Check information
#Find missing values
#Remove duplicates
#Rename
#CustomerID
#AnnualIncome
#CreditScore
#Target
#Convert
#Age
#AnnualIncome
#Balance
#Fill missing values
#Remove
#Segment
#CustomerID
#Create new columns
#TotalMoney = Balance + AnnualIncome
#AgeAfter5Years = Age + 5
#MonthlyIncome = AnnualIncome / 12
#CreditScoreDouble = CreditScore * 2Display
#• Head
#• Tail
#• Sample
#• Describe
#• Target counts
#• Final information

import pandas as pd
df2 = pd.read_csv("C:\\Users\\DELL\\Downloads\\Task_dataset - Task_dataset.csv")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df2.isnull().sum()
# Out:
# CustomerID       0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df2.drop_duplicates(inplace=True)
df2
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
# ...

# %%
df2.rename(columns={"CustomerID": "Customer_ID","AnnualIncome": "Income",
    "CreditScore": "Credit_Score","Target": "Customer_Status"}, inplace=True)
df2["Age"] = df2["Age"].fillna(df2["Age"].median())
df2["Income"] = df2["Income"].fillna(df2["Income"].median())
df2["Balance"] = df2["Balance"].fillna(df2["Balance"].mean())
df2["Age"] = df2["Age"].astype(int)
df2["Income"] = df2["Income"].astype(float)
df2["Balance"] = df2["Balance"].astype(float)
df2.drop(columns=["Segment", "Customer_ID"], inplace=True)
df2["TotalMoney"] = df2["Balance"] + df2["Income"]
df2["AgeAfter5Years"] = df2["Age"] + 5
df2["MonthlyIncome"] = df2["Income"] / 12
df2["CreditScoreDouble"] = df2["Credit_Score"] * 2
df2.head()
# Out:
#    Age    Income  Spending  Credit_Score        Balance  Tenure Geography  \
# 0   58   49184.0      2139           581   97557.565779       2    France
# 1   65  162964.0      6197           732    6356.540000       1       USA
# 2   56   26956.0     37281           503  143203.920000       8    Canada
# 3   55   92926.0       925           463  139627.880000       5       NaN
# 4   66  108236.0      7198           394   75985.460000       5        UK
#
#   Gender Customer_Status     TotalMoney  AgeAfter5Years  MonthlyIncome  \
# 0   Male            Stay  146741.565779              63    4098.666667
# 1   Male           Churn  169320.540000              70   13580.333333
# 2   Male            Stay  170159.920000              61    2246.333333
# 3   Male           Churn  232553.880000              60    7743.833333
# 4  Other           Churn  184221.460000              71    9019.666667
#
#    CreditScoreDouble
# 0               1162
# 1               1464
# 2               1006
# ...

# %%
df2.tail()
# Out:
#      Age    Income  Spending  Credit_Score    Balance  Tenure Geography  \
# 995   34   81731.0     40980           761  181465.65       5   Germany
# 996   47   42475.0      1176           780   26640.99       5    France
# 997   31  120531.0     46929           733  147220.82       4     India
# 998   21   33661.0     22314           540   94186.48       5       NaN
# 999   63   31930.0       851           559  100908.40       6        UK
#
#      Gender Customer_Status  TotalMoney  AgeAfter5Years  MonthlyIncome  \
# 995   Other            Stay   263196.65              39    6810.916667
# 996  Female            Stay    69115.99              52    3539.583333
# 997    Male            Stay   267751.82              36   10044.250000
# 998   Other            Stay   127847.48              26    2805.083333
# 999  Female            Stay   132838.40              68    2660.833333
#
#      CreditScoreDouble
# 995               1522
# 996               1560
# 997               1466
# ...

# %%
df2.sample(10)
# Out:
#      Age    Income  Spending  Credit_Score    Balance  Tenure Geography  \
# 715   38  110315.0     39420           324  153936.26       2        UK
# 769   69   29321.0     42813           439   96299.10      10    Canada
# 954   40   34797.0     43835           550   49522.79      10        UK
# 905   41  124217.0     10195           737   73925.99       5     India
# 737   48  190280.0     25007           488  170425.89       7    Canada
# 893   68   88159.0     15362           795   74380.46       4     India
# 551   27   33910.0     44425           357   39980.48       2        UK
# 163   64  112347.5     28685           762  177618.20       6        UK
# 341   68  105047.0     25746           312   58369.47       6     India
# 183   23  134481.0      7437           549   87135.31       6   Germany
#
#      Gender Customer_Status  TotalMoney  AgeAfter5Years  MonthlyIncome  \
# 715   Other           Churn   264251.26              43    9192.916667
# ...

# %%
df2.describe()
# Out:
#                Age         Income      Spending  Credit_Score        Balance  \
# count  1000.000000    1000.000000   1000.000000   1000.000000    1000.000000
# mean     44.202000  112452.763000  25285.558000    603.088000   97557.565779
# std      15.130834   51081.480963  14211.735656    176.605486   54430.062006
# min      18.000000   20227.000000    537.000000    300.000000     547.600000
# 25%      31.000000   68437.250000  13213.000000    441.000000   52074.240000
# 50%      44.000000  112347.500000  24901.000000    606.500000   97557.565779
# 75%      57.000000  155570.750000  37960.250000    758.250000  142297.910000
# max      70.000000  199967.000000  49995.000000    900.000000  199885.880000
#
#             Tenure     TotalMoney  AgeAfter5Years  MonthlyIncome  \
# count  1000.000000    1000.000000     1000.000000    1000.000000
# mean      5.241000  210010.328779       49.202000    9371.063583
# std       3.179155   73150.769298       15.130834    4256.790080
# ...

# %%
df2["Customer_Status"].value_counts()
# Out:
# Customer_Status
# Churn    506
# Stay     494
# Name: count, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                1000 non-null   int64
#  1   Income             1000 non-null   float64
#  2   Spending           1000 non-null   int64
#  3   Credit_Score       1000 non-null   int64
#  4   Balance            1000 non-null   float64
#  5   Tenure             1000 non-null   int64
#  6   Geography          950 non-null    object
#  7   Gender             950 non-null    object
#  8   Customer_Status    1000 non-null   object
#  9   TotalMoney         1000 non-null   float64
#  10  AgeAfter5Years     1000 non-null   int64
#  11  MonthlyIncome      1000 non-null   float64
#  12  CreditScoreDouble  1000 non-null   int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 109.4+ KB
