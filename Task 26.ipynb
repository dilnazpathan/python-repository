# %% [markdown]
# ### Basic Exception Handling (1-10)

# %%
# 1. Write a program that takes two numbers and performs division. Handle the ZeroDivisionError.

try:
    num1 = float(input("enter first number:"))
    num2 = float(input("enter second number:"))
    result = num1 / num2
    print("result:",result)
except ZeroDivisionError:
    print("error: cannot divide by zero")
# Out:
# enter first number: 2324
# enter second number: 0
# error: cannot divide by zero

# %%
# 2. Take a number from user and convert it to integer. Handle ValueError if user enters a string.

try:
    num = int(input("enter a number:"))
    print("integer value:",num)
except ValueError:
    print("error:please enter valid integer")
# Out:
# enter a number: 32.1
# error:please enter valid integer

# %%
# 3. Access an element from a list using index. Handle IndexError.

try:
    numbers = [10,20,30,40,50]
    index = int(input("enter the number:"))
    print("element:",numbers[index])
except IndexError:
    print("error: index is out of range")
# Out:
# enter the number: 4
# element: 50

# %%
# 4. Try to open a file that does not exist. Handle FileNotFoundError.

try:
    file = open("example.txt","r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("error: file not found")
# Out:
# error: file not found

# %%
# 5. Create a dictionary and access a key that does not exist. Handle KeyError.

try:
    student = {
        "name":"dilnaz",
        "age":23,
        "course":"MCA"
    }
    key = input("enter the key:")
    print("value=",student[key])
except KeyError:
    print("error: key does not exist in the dictionary")
# Out:
# enter the key: course
# value= MCA

# %%
# 6. Write a program using try-except to handle multiple exceptions (ValueError and ZeroDivisionError).

try:
    num1 = int(input("enter first number:"))
    num2 = int(input("enter second number:"))
    result = num1 / num2
    print("result:",result)
except ValueError:
    print("error: please enter valid integer")
except ZeroDivisionError:
    print("error: division by zero is not allowed")
# Out:
# enter first number: 45
# enter second number: 32.1
# error: please enter valid integer

# %%
# 7. Demonstrate the use of else block with try-except.

try:
    num1 = int(input("enter first number:"))
    num2 = int(input("enter second number:"))
    result = num1 / num2
    
except ZeroError:
    print("error: division by zero is not allowed")
except ValueError:
    print("error: please enter valid integer")
else:
    print("result:",result)
    print("division completed successfully")
# Out:
# enter first number: 34
# enter second number: 23
# result: 1.4782608695652173
# division completed successfully

# %%
# 8. Demonstrate the use of finally block with an example.

try:
    num1 = int(input("enter first number:"))
    num2 = int(input("enter second number:"))
    result = num1 / num2
    print("result:",result)
except ZeroError:
    print("division is not possible by zero")
except ValueError:
    print("please enter valid integer")
finally:
    print("program executed successfully")
# Out:
# enter first number: 23
# enter second number: 1
# result: 23.0
# program executed successfully

# %%
# 9. Take age as input. Raise an exception if age is negative.

try:
    age = int(input("enter age:"))
    if age < 0:
        raise ValueError("age cannot be negative")
    print("your age:",age)
except ValueError as e:
    print("error:",e)
# Out:
# enter age: 23
# your age: 23

# %%
# 10. Write a program that handles TypeError when adding string and integer.

try:
    text = "100"
    number = 50
    result = text + number
    print("result",result)
except ValueError:
    print("error: cannot add string and integer")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 6
#       4     text = "100"
#       5     number = 50
# ----> 6     result = text + number
#       7     print("result",result)
#       8 except ValueError:
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### Multiple Exceptions & Specific Handling (11-18)

# %%
# 11. Handle ZeroDivisionError and ValueError in the same program using multiple except blocks.


try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    result = num1 / num2
    print("Result =", result)
except ValueError:
    print("Error: Please enter valid integer values.")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Enter first number:  4
# Enter second number:  0
# Error: Division by zero is not allowed.

# %%
# 12. Use a single except block to handle any exception and print the error message.

try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    result = num1 / num2
    print("Result =", result)
except Exception as e:
    print(e)
# Out:
# Enter first number:  20
# Enter second number:  2
# Result = 10.0

# %%
# 13. Demonstrate nested try-except blocks.
try:
    num1 = int(input("Enter first number: "))
    try:
        num2 = int(input("Enter second number: "))
        result = num1 / num2
        print("result:",result)
    except ZeroDivision:
        print("error: division with zero is not possible")
except ValueError:
    print("error: please enter valid integer")
# Out:
# Enter first number:  2
# Enter second number:  4
# result: 0.5

# %%
# 14. Write a program that handles IndexError and KeyError separately.

try:
    numbers = [10,20,30,40]
    index = int(input("enter the list index"))
    print("list element:",numbers[index])
    student = {
         "name":"dilnaz",
         "age": 23,
         "course": "MCA"
    }
    key = input("enter the dictionary key:")
    print("value:",student[key])
except IndexError:
    print("error: list index is out of range")
except KeyError:
    
    print("error: key does not exist in the dictionary")
# Out:
# enter the list index 2
# list element: 30
# enter the dictionary key: age
# value: 23

# %%
# 15. Take a list and a dictionary. Perform operations and handle possible exceptions.

try:
    numbers = [10,20,30,40,50]
    student = {
        "name" : "dilnaz",
        "age" : 23,
        "course" : "MCA"
    }
    index = int(input("enter list index:"))
    print("list element =", numbers[index])
    key = input("enter dictionary key:")
    print("dictionary value=",student[key])
except IndexError:
    print("error: index is out of range")
except KeyError:
    print("error: dictionary key does not exist")
except ValueError:
    print("error: please enter a valid integer for the list index")
# Out:
# enter list index: 2
# list element = 30
# enter dictionary key: course
# dictionary value= MCA

# %%
# 16. Create a program that catches AttributeError when calling a non-existing method.

try: 
    text = "hello"
    text.uppercase()
except AttributeError:
    print("error: method doesnot exist")
# Out:
# error: method doesnot exist

# %%
# 17. Handle NameError when using a variable that is not defined.

try:
    print(value)
except NameError:
    print("error: variable is not defined")
# Out:
# error: variable is not defined

# %%
# 18. Write a program using try-except-else-finally all together.

try:
    num1 = int(input("enter first number:"))
    num2 = int(input("enter second number:"))
    result = num1 / num2
except ValueError:
    print("error: please enter valid integer")
except ZeroDivisionError:
    print("error: cannot divide by zero")
else:
    print("result = " ,result)
    print("division completed successfully")
finally:
    print("program execution completed")
# Out:
# enter first number: 2
# enter second number: 5
# result =  0.4
# division completed successfully
# program execution completed

# %% [markdown]
# ### Raising Exceptions & Custom Exceptions (19-25)

# %%
# 19. Write a function that takes age and raises ValueError if age is less than 18.

def check_age(age):
    if age < 18:
        raise ValueError("age must be 18 or above")
    else:
        print("eligible age is :",age)
try:
    age = int(input("enter your age:"))
    check_age(age)
except ValueError as e:
    print(e)
# Out:
# enter your age: 23
# eligible age is : 23

# %%
# 20. Create a custom exception called NegativeNumberError and raise it when user enters a negative number.

class NegativeNumberError(Exception):
    pass
try:
    num = int(input("enter a number:"))
    if num < 0:
        raise NegativeNumberError("negative number is not allowed")
    print("you entered:",num)
except NegativeNumberError as e:
    print(e)
# Out:
# enter a number: 45
# you entered: 45

# %%
# 21. Create a custom exception InsufficientBalanceError for a banking program.

class InsufficientBalanceError(Exception):
    pass
try:
    balance = 5000
    amount = float(input("enter withdrawal amount:"))
    if amount > balance:
        raise InsufficientBalanceError("insufficient balance")
    balance = balance - amount
    print("withdrawal successful")
    print("remaining balance =",balance)
except InsufficientBalanceError as e:
    print(e)
# Out:
# enter withdrawal amount: 2000
# withdrawal successful
# remaining balance = 3000.0

# %%
# 22. Write a program that raises TypeError manually if the input is not a string.

try:
    data = 100
    if not isinstance(data,str):
        raise TypeError("input is not a string")
    print(data)
except TypeError as e:
    print(e)
# Out:
# input is not a string

# %%
# 23. Create a function that checks password length and raises a custom exception if length is less than 8.

class PasswordLengthError(Exception):
    pass
def check_password(password):
    if len(password) < 8:
        raise PasswordLengthError("password must be at least 8 character long")
    else:
        print("password accepted")
try:
    password = input("enter password")
    check_password(password)
except PasswordLengthError as e:
    print(e)
# Out:
# enter password dilnaz1234
# password accepted

# %%
# 24. Demonstrate how to raise an exception with a custom error message.

try:
    num = int(input("enter a positive number"))
    if num < 0:
        raise Exception("custom error: neagtive numbers are not allowed")
    print("you entered:",num)
except Exception as e:
    print(e)
# Out:
# enter a positive number -9
# custom error: neagtive numbers are not allowed

# %%
# 25. Write a program that uses raise to force an exception and handles it.

try:
    num = int(input("Enter a number: "))
    if num < 0:
        raise Exception("Negative numbers are not allowed.")
    print("You entered:", num)
except Exception as e:
    print(e)
# Out:
# Enter a number:  6
# You entered: 6

# %% [markdown]
# ### Practical / Hard Questions (26-30)

# %%
# 26. Create a simple calculator that handles ZeroDivisionError, ValueError and invalid operator.

try:
    num1 = float(input("enter first number:"))
    operator = input("enter operator (+,-,*,/):")
    num2 = float(input("enter second number:"))
    if operator == "+":
        print("result =",num1 + num2)
    elif operator == "-":
        print("result =",num1 - num2)
    elif operator == "*":
        print("result =", num1 * num2)
    elif operator == "/":
        print("result =",num1 / num2)
    else:
        raise Exception("invalid operator")
except ValueError:
    print("error: please enter valid number")
except ZeroDivisionError:
    print("error: enter valid number")
except Exception as e:
    print(e)
# Out:
# enter first number: 5
# enter operator (+,-,*,/): +
# enter second number: 78
# result = 83.0

# %%
# 27. Write a program to read a file. Handle FileNotFoundError and PermissionError.

try:
    file = open("sample.txt","r")
    print(file.read())
    file.close()
except FileNotFoundError:
    print("error: file not found")
except PermissionError:
    print("error: permission denied")
# Out:
# error: file not found

# %%
# 28. Create a banking system with deposit and withdraw. Raise and handle custom exception for insufficient balance.



class InsufficientBalanceError(Exception):
    pass
balance = 5000
try:
    amount = float(input("Enter deposit amount: "))
    balance += amount
    print("Balance after deposit =", balance)
    amount = float(input("Enter withdrawal amount: "))
    if amount > balance:
        raise InsufficientBalanceError("Insufficient balance.")
    balance -= amount
    print("Withdrawal successful.")
    print("Remaining balance =", balance)
except InsufficientBalanceError as e:
    print("Error:", e)
# Out:
# Enter deposit amount:  4000
# Balance after deposit = 9000.0
# Enter withdrawal amount:  2000
# Withdrawal successful.
# Remaining balance = 7000.0

# %%
# 29. Take a list of numbers from user (as string). Convert them to integers and handle any conversion errors.

try:
    data = input("enter number seperated by space:")
    numbers = [int(num) for num in data.split()]
    print("integer list =", numbers)
except ValueError:
    print("error: please enter only valid integers")
# Out:
# enter number seperated by space: 1 3 6  7  8
# integer list = [1, 3, 6, 7, 8]

# %%
# 30. Write a complete program that accepts user input for name, age and marks. Handle all possible exceptions and use finally to print
#“Program Ended”.


try:
    name = input("Enter your name: ")

    if not name.isalpha():
        raise ValueError("Name should contain only letters.")

    age = int(input("Enter your age: "))
    marks = float(input("Enter your marks: "))

    if age < 0:
        raise ValueError("Age cannot be negative.")

    if marks < 0 or marks > 100:
        raise ValueError("Marks should be between 0 and 100.")

    print("\nStudent Details")
    print("Name :", name)
    print("Age :", age)
    print("Marks :", marks)

except ValueError as e:
    print("Error:", e)

finally:
    print("Program Ended")
# Out:
# Enter your name:  dilnaz
# Enter your age:  23
# Enter your marks:  90
# Student Details
# Name : dilnaz
# Age : 23
# Marks : 90.0
# Program Ended
