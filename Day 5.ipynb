# %% [markdown]
# ### Easy level

# %%
# question 1 Create a list named students with 5 student names and print it.

students= ["dilnaz","tanmayi","ruchika","mahi","sakshi"]
print(students)
# Out:
# ['dilnaz', 'tanmayi', 'ruchika', 'mahi', 'sakshi']

# %%
# question 2 Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().

numbers = [10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
# question 3 Create an empty list and append 3 numbers into it using append().

numbers =[]
numbers.append([10,20,30])

print(numbers)
# Out:
# [[10, 20, 30]]

# %%
# question 4 Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.

lst = [1, 2, 3]
lst.extend([4,5,6])
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# question 5 Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].

numbers = [10, 20, 30, 40]
numbers.insert(2,100)
print(numbers)
# Out:
# [10, 20, 100, 30, 40]

# %%
# question 6 Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().

numbers = [10,20,30,40,50]
numbers.remove(50)
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
# question 7 Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.

numbers = [5,10,15,20]
numbers.pop()
print(numbers)
# Out:
# [5, 10, 15]

# %%
# question 8 Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().

data = [1,2,3,4,5]
data.clear()
print(data)
# Out:
# []

# %% [markdown]
# ### Medium level

# %%
# question 9 Find the index of 25 in the list [10, 15, 25, 30, 40] using index().

numbers = [10,15,25,30,40]
print(numbers.index(25))
# Out:
# 2

# %%
# question 10 Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count().

num = [7,2,7,5,7,8]
print(num.count(7))
# Out:
# 3

# %%
# question 11 Sort the list [45, 12, 78, 23, 56] in ascending order using sort().

number = [45,12,78,23,56]
number.sort()
print(numbers)
# Out:
# [10, 15, 25, 30, 40]

# %%
# question 12 Sort the list [45, 12, 78, 23, 56] in descending order.

numbers = [45, 12, 78, 23, 56]
numbers.sort(reverse = True)
print(numbers)
# Out:
# [78, 56, 45, 23, 12]

# %%
# question 13 Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse().

fruits = ["apple", "banana", "mango", "orange"]
fruits.reverse()
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
# question 14 Create a copy of list original = [1, 2, 3, 4] using copy() and print both.

original = [1, 2, 3, 4] 
original.copy()
print(original)
# Out:
# [1, 2, 3, 4]

# %%
# question 15 Take a sentence from user (e.g. "I love Python programming") and convert it into a list of words using split().

sentence = input("Enter a sentence: ")
words = sentence.split()
print("list of words:",words)
# Out:
# Enter a sentence:  i love python programming
# list of words: ['i', 'love', 'python', 'programming']

# %% [markdown]
# ### Hard/Mixed level

# %%
# question 16 Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order.

numbers = [34,64,12,45,32]
numbers.append(90)
numbers.append(67)
numbers.append(43)
print(numbers)
numbers.sort(reverse = True)
print(numbers)
# Out:
# [34, 64, 12, 45, 32, 90, 67, 43]
# [90, 67, 64, 45, 43, 34, 32, 12]

# %%
# question 17 Create a list. Insert "Python" at index 0, then remove the last element using pop(), and print the length.

number = ["java","c","c sharp"]
number.insert(0,"Python")
number.pop()
print(number)
print(len(number))
# Out:
# ['Python', 'java', 'c']
# 3

# %%
# question 18 Take 5 city names as input from user and store them in a list. Then print them in reverse order.

cities=[ input("enter city 1:"),
         input("enter city 2:"),
         input("enter city 3:"),
         input("enter city 4:"),
         input("enter city 5:")
       ]
cities.sort(reverse=True)
print(cities)
# Out:
# enter city 1: hyd
# enter city 2: delhi
# enter city 3: mumbai
# enter city 4: banglore
# enter city 5: pune
# ['pune', 'mumbai', 'hyd', 'delhi', 'banglore']

# %%
# question 19 Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20 (use loop or multiple remove).

data = [10, 20, 30, 20, 40, 20]
data.remove(20)
data.remove(20)
data.remove(20)
print(data)
# Out:
# [10, 30, 40]

# %%
# question 20 Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.

marks = [56,78,87,90,67]
marks.sort()
print(marks)
print(marks[0])
print(marks[-1])
# Out:
# [56, 67, 78, 87, 90]
# 56
# 90
