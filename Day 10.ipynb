# %%
# question 1 Take a number as input. If the number is positive, check whether it is even or odd and print the result.

num = int(input("Enter a number:"))
if num > 0:
    if num % 2 == 0:
        print("positive and even number")
    else:
        print("positive and odd number")
else:
    print("number is not positive")
# Out:
# Enter a number: 0
# number is not positive

# %%
# question 2 Take age as input. If age is greater than or equal to 18, check if the person is a senior citizen (age >= 60) or adult.

age = int(input("Enter your age:"))
if age >= 18:
    if age >= 60:
        print("person is senior citizen")
    else:
        print("person is adult")
else:
    print("person is minor")
# Out:
# Enter your age: 12
# person is minor

# %%
# question 3 Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.

ch = input("Enter a character:")
if ch.isalpha():
    if ch.isupper():
        print("alphabet is in uppercase")
    else:
        print("alphabet is in lowercase")
else:
    print("It is not character")
# Out:
# Enter a character: 1
# It is not character

# %%
# quesrtion 4 Take three numbers as input and print the largest number using nested if statements (without using max()).

num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
num3 = int(input("Enter third number:"))
if num1 > num2:
    if num1 > num3:
        print("num1 is largest")
    else:
        print("num2 is largest")
else:
    print("num3 is largest")
# Out:
# Enter first number: 34
# Enter second number: 32
# Enter third number: 23
# num1 is largest

# %%
# question 5 Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to print "Pass with Distinction".

marks = int(input("Enter marks:"))
if marks >= 40:
    if marks >= 70:
        print("Pass with Distinction")
    else:
        print("Pass")
else:
    print("Failed")
# Out:
# Enter marks: 41
# Pass

# %%
# question 6 Take a number. If it is divisible by 2, check if it is also divisible by 4.

num = int(input("Enter number:"))
if num % 2 == 0:
    if num % 4 == 0:
        print("num is divisible by 2 and 4")
    else:
        print("num is divisible by only 2")
else:
    print("num is not divisivle by 2 ")
# Out:
# Enter number: 24
# num is divisible by 2 and 4

# %%
# question 7 Take username and password. If username is "admin", then check if the password is correct.

username = input("Enter username:")
password = input("Enter password:")
if username == "admin":
    if password == "Python123":
        print("login successful")
    else:
        print("login failed")
else:
    print("invalid login")
# Out:
# Enter username: admin
# Enter password: Python123
# login successful

# %%
# question 8 Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.

a = int(input("Enter first side:"))
b = int(input("enter second side:"))
c = int(input("enter third side:"))
if a == b and b == c and c == a:
    print("valid triangle")
    if a == b == c:
        print("equilateral triangle")
    else:
        print("Isosceles triangle")
else:
    print("Scalene triangle")
# Out:
# Enter first side: 23
# enter second side: 34
# enter third side: 45
# Scalene triangle

# %%
# question 9 Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".

salary = int(input("enter your salary:"))
experience = int(input("enter your experience:"))
if salary > 50000:
    if experience >= 5:
         print(" Senior Manager")
    else:
        print(" Senior Manager")
else:
    print("Employee")
# Out:
# enter your salary: 500000
# enter your experience: 8
#  Senior Manager

# %%
# question 10 Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit, print "Digit". Else print "Special Character".

ch = input("enter a character:")
if ch.isalpha():
    if ch.lower() in "aeiou":
        print("vowel")
    else:
        print("consonent")
elif ch.isdigit():
    print("Digit")
else:
    print("Special character")
# Out:
# enter a character: @
# Special character

# %%
# question 11 Take a year as input. Check if it is a leap year using nested conditions.

year = int(input("enter year:"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("leap year")
        else:
            print("not a leap year")
    else:
        print("leap year")
else:
    print("not a leap year")
# Out:
# enter year: 2003
# not a leap year

# %%
# question 12 Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm",else "Cold" using nested if.

temp = float(input("enter temperature:"))
if temp > 30:
    print("Hot")
else:
    if temp >= 20:
        print("Warm")
    else:
        print("Cold")
# Out:
# enter temperature: 6
# Cold

# %%
# question 13 Take three numbers. Check if all three are equal, or any two are equal using nested if.

num1 = int(input("enter first number:"))
num2 = int(input("enter second number:"))
num3 = int(input("enter third number:"))
if num1 == num2 == num3:
    print("All three numbers are equal")
elif num1 == num2 or num2 == num3 or num1 == num3:
    print("Two numbers are equal")
else:
    print("All three numbers are different")
# Out:
# enter first number: 32
# enter second number: 23
# enter third number: 23
# Two numbers are equal

# %%
# question 14 Take a number. If it is positive and even, print "Positive Even Number".

num =  int(input("Enter a number:"))
if num > 0:
    if num % 2 == 0:
        print("number is positive and even")
    else:
        print("number is positive and odd")
else:
    print("number is negative")
# Out:
# Enter a number: 34
# number is positive and even

# %%
# question 15 Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.

marks1 = int(input("enter marks of first subject:"))
marks2 = int(input("enter marks of second subject:"))
marks3 = int(input("enter marks of third subject:"))
marks4 = int(input("enter marks of fourth subject:"))
marks5 = int(input("enter marks of fifth subject:"))
average = (marks1+marks2+marks3+marks4+marks5)/5
if average >= 60:
    if marks1 > 40 and marks2 > 40 and marks3 > 40 and marks4 > 40 and marks > 40:
        print("average:",average)
        print("all subject are above 40")
    else:
        print("average is above 60 but some subjects are below 40")
else:
    print("average is below 40")
# Out:
# enter marks of first subject: 78
# enter marks of second subject: 98
# enter marks of third subject: 90
# enter marks of fourth subject: 89
# enter marks of fifth subject: 80
# average: 87.0
# all subject are above 40

# %%
# question 16 Take username, password, and age. If username and password are correct and age >= 18, print "Login Successful".
# Else if age < 18, print age restriction message.

username = input("enter username:")
password = input("enter password:")
age = int(input("enter age:"))
if username == "admin" and password == "Python123":
    if age >= 18:
        print("login successful")
    else:
        print("age restricted")
else:
    print("invalid username and password")
# Out:
# enter username: admin
# enter password: Python123
# enter age: 23
# login successful

# %%
# question 17 Take a number. Check if it is divisible by both 3 and 5 using nested if.

num  = int(input("enter a number:"))
if num % 3 == 0:
    if num % 5 == 0:
        print("number is divisible by 3 and 5")
    else:
        print("number is divisible by 3 only")
else:
    print("number is not divisible by both 3 and 5")
# Out:
# enter a number: 15
# number is divisible by 3 and 5

# %%
# question 18 Take three sides of a triangle. Check if valid, then check if it is a right-angled triangle using Pythagoras theorem.

a = int(input("enter first side:"))
b = int(input("enter second side:"))
c = int(input("enter third side:"))
if a + b > c and b + c > a and c + a > b:
    print("valid triangle")
    sides = sorted([a,b,c])
    if sides [0]**2 + sides[1]**2 == sides[2]**2:
        print("right angled triangle")
    else:
        print("not a right angled triangle")
else:
    print("invalid triangle")
# Out:
# enter first side: 2
# enter second side: 3
# enter third side: 5
# invalid triangle

# %%
# question 19 Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent, Good, Average, etc.).

grade = input("enter grade(A/B/C/D/E):").upper()
if grade == "A":
    print("Excellent")
elif grade == "B":
    print("good")
elif grade == "C":
    print("Average")
elif grade == "D":
    print("Below average")
elif grade == "F":
    print("Failed")
else:
    print("invalid grade")
# Out:
# enter grade(A/B/C/D/E): A
# Excellent

# %%
# question 20 Take income. If income > 1000000, check tax slab. If income between 500000-1000000, different slab. Else print "Low Income".

income = int(input("enter your income:"))
if income > 1000000:
    print("high level slab")
elif income >= 5000000:
    print("low level slab")
else:
    print("low income")
# Out:
# enter your income: 1000000
# low income

# %%
# question 21 Take three sides of a triangle as input. First check if they can form a valid triangle (sum of any two sides > third side). If valid, 
# then further check and print whether the triangle is Equilateral, Isosceles, or Scalene.

a = int(input("enter first side:"))
b = int(input("enter second side:"))
c = int(input("enter third side:"))
if a + b > c and b + c > a and a + c > b:
    print("valid triangle")
    if a == b == c:
        print("equilateral triangle")
    elif a == b or b == c or c == a:
        print("isosceles triangle")
    else:
        print("Scalene triangle")
else:
    print("invalid triangle")
# Out:
# enter first side: 23
# enter second side: 23
# enter third side: 23
# valid triangle
# equilateral triangle

# %%
# question 22 Take a student's marks in 5 subjects. Calculate the average. If average >=60, then check if all individual subjects are above 40. 
# If yes, print "Pass with Good Performance", else print "Pass but Weak in some subjects". If average < 60, print "Fail".

m1 = int(input("enter first subject marks:"))
m2 = int(input("enter second subject marks:"))
m3 = int(input("enter third subject marks:"))
m4 = int(input("enter fourth subject marks:"))
m5 = int(input("enter fifth subject marks:"))
average = (m1+m2+m3+m4+m5)/5
if average >= 60:
    if m1 > 40 and m2 > 40 and m3 > 40 and m4 > 40 and m5 > 40:
        print("pass with good performance")
    else:
        print("pass but weak in some subject")
else:
    print("Fail")
# Out:
# enter first subject marks: 45
# enter second subject marks: 56
# enter third subject marks: 78
# enter fourth subject marks: 89
# enter fifth subject marks: 98
# pass with good performance

# %%
# question 23 Take username, password, and age as input.
# • If username == "admin" and password == "python123" and age >= 18, print "Login Successful".
# • Else if age < 18, print "You are too young to login".
# • Else if username is wrong, print "Invalid Username".
# • Else print "Invalid Password".

username = input("enter username:")
password = input("enter password:")
age = int(input("enter your age:"))
if username == "admin" and password == "python123" and age >= 18:
    print("login successful")
elif age < 18:
    print("You are too young to login")
elif username != 0:
    print("Invalid username")
else:
    print("Invalid pssword")
# Out:
# enter username: admin
# enter password: python123
# enter your age: 19
# login successful

# %%
# question 24 Take a number as input. Check if the number is positive. If positive, check
# if it is divisible by both 3 and 5. If yes, print "FizzBuzz". If only divisible by 3 print
# "Fizz", only by 5 print "Buzz". If negative, print "Negative Number".

number = int(input("enter number:"))
if number > 0:
    if number % 3 == 0 and number % 5 == 0:
        print("FizzBuzz")
    elif number % 3 == 0:
        print("Fizz")
    elif number % 5 == 0:
        print("Buzz")
    else:
        print("not divisible by 3 and 5")
else:
    print("negative number")
# Out:
# enter number: 45
# FizzBuzz

# %%
# question 25 Take three numbers. First check if all three are equal. If not, check which one is the largest. 
# Also check if the largest number is even or odd and print all information accordingly.

num1 = int(input("enter first number:"))
num2 = int(input("enter second number:"))
num3 = int(input("enter third number:"))
if num1 == num2 == num3:
    print("all three are equal")
else:
    if num1 >= num2 and num1 >= num3:
        largest = num1
    elif num2 >= num1 and num2 >= num3:
        largest = num2
    else:
        largest = num3
    print("largest number=",largest)
    if largest % 2 == 0:
        print("largest number is even")
    else:
        print("largest number is odd")
# Out:
# enter first number: 90
# enter second number: 98
# enter third number: 78
# largest number= 98
# largest number is even
