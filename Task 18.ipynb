# %% [markdown]
# ### Encapsulation Practice Questions (1–15)

# %%
# question 1 Class Name: BankAccount
#Problem
#Create a class named BankAccount.
#Explanation
#A bank account stores money. The balance should not be directly accessible from outside the class, so create a private attribute named __balance.
#Implement the following methods:
#• deposit(amount)
#o Deposit money into the account.
#o Amount must be greater than 0.
#• withdraw(amount)
#o Withdraw money.
#o Withdrawal should happen only if:
#▪ amount > 0
#▪ amount <= available balance

class BankAccount:
    def __init__(self):
        self.__balance = 0
    def deposite(self,amount):
        if amount >  0:
            self.__balance += amount
            print("Deposited:",amount)
        else:
            print("amount must be greate than 0")
    def withdraw(self,amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print("withdraw:", amount)
        else:
            print("invalid withdrawal")
    def get_balance(self):
        return self.__balance
account = BankAccount()
account.deposite(5000)
account.withdraw(2000)
print("balance:",account.get_balance())
account.withdraw(4000)
# Out:
# Deposited: 5000
# withdraw: 2000
# balance: 3000
# invalid withdrawal

# %%
# question 2 Class Name: Student
#Problem
#Create a class named Student.
#Explanation
#Every student has marks that should be private.
#Create:
#• Private attribute __marks
#Methods:
#• set_marks(marks)
#o Accept marks only between 0 and 100.
#• get_marks()
#o Return the student's marks.

class Student:
    def __init__(self):
        self.__marks = 0
    def set_marks(self,marks):
        if 0 <= marks <= 100:
            self.__marks = marks
        else:
            print("marks should be between 0 and 100")
    def get_marks(self):
        return self.__marks
s = Student()
s.set_marks(60)
print("marks:",s.get_marks())
s.set_marks(125)
print("marks:",s.get_marks())
# Out:
# marks: 60
# marks should be between 0 and 100
# marks: 60

# %%
# question 3 Class Name: Employee
#Problem
#Create a class named Employee.
#Explanation
#Salary should not be modified directly.
#Create:
#• Private attribute __salary
#Methods:
#• set_salary(new_salary)
#o Salary cannot decrease by more than 10% of the current salary.
#• get_salary()
#Example:
#Current Salary = 50,000
#Allowed minimum = 45,000
#New salary = 40,000
#Reject

class Employee:
    def __init__(self,salary):
        self.__salary = salary
    def set_salary(self,new_salary):
        minimum_salary = self.__salary*0.9
        if new_salary >= minimum_salary:
            self.__salary = new_salary
            print("salary updated successfully.")
        else:
            print("Rejected! salary cannot decrease by more than 10%")
    def get_salary(self):
        return self.__salary
emp = Employee(50000)

print("current salary:",emp.get_salary())
emp.set_salary(45000)
print("updated salary:",emp.get_salary())
emp.set_salary(40000)
print("final salary:",emp.get_salary())
# Out:
# current salary: 50000
# salary updated successfully.
# updated salary: 45000
# Rejected! salary cannot decrease by more than 10%
# final salary: 45000

# %%
# question 4 Class Name: Mobile
#Problem
#Create a class named Mobile.
#Explanation
#Price should always be positive.
#Private attribute:
#• __price
#Methods:
#• set_price(price)
#• get_price()
#Validation:
#Price > 0

class Mobile:
    def __init__(self,price):
        self.__price = 0
        self.set_price(price)
    def set_price(self,price):
        if  price > 0:
            self.__price = price
        else:
            print("price must be greater than 0")
    def get_price(self):
        return self.__price
m = Mobile(50000)
print("price:",m.get_price())
m.set_price(30000)
print("price:",m.get_price())
m.set_price(-5000)
print("price:",m.get_price())
# Out:
# price: 50000
# price: 30000
# price must be greater than 0
# price: 30000

# %%
# question 5 Class Name: Person
#Problem
#Create a class named Person.
#Explanation
#Store age privately.
#Private attribute:
#• __age
#Methods:
#• set_age(age)
#• get_age()
#Validation:
#Age should be between 0 and 120

class Person:
    def __init__(self,age):
        self.__age = age
    def set_age(self,age):
        if 0 <= age <= 120:
            self.__age = age
        else:
            print("age should be between 0 and 120")
    def get_age(self):
        return self.__age
p = Person(23)
print("age:",p.get_age())
p.set_age(125)
print("age:",p.get_age())
# Out:
# age: 23
# age should be between 0 and 120
# age: 23

# %%
# question 6 Class Name: Product
#Problem
#Create a class named Product.
#Explanation
#Store
#• private __price
#• private __stock
#Methods:
#• update_price(new_price)
#• update_stock(quantity)
#Validation:
#Price cannot be negative.
#Stock cannot become negative.

class Product:
    def __init__(self,price,stock):
        self.__price = 0
        self.__stock = 0
        self.updated_price(price)
        self.updated_stock(stock)
    def updated_price(self,new_price):
        if new_price >= 0:
            self.__updated_price = new_price
        else:
            print("price cannot be negative")
    def updated_stock(self,quantity):
        if quantity >= 0:
            self.__updated_stock = quantity
        else:
            print("stock cannot be negative")
    def get_price(self):
        return self.__price

    def get_stock(self):
        return self.__stock
p = Product(500,20)
print("price:",p.get_price())
print("stock:",p.get_stock())
p.updated_price(700)
p.updated_stock(30)
print("price:",p.get_price())
print("stock:",p.get_stock())
p.updated_price(-5000)
p.updated_stock(-5)
# Out:
# price: 0
# stock: 0
# price: 0
# stock: 0
# price cannot be negative
# stock cannot be negative

# %%
# question 7 Class Name: Car
#Problem
#Create class Car.
#Explanation
#Store privately
#• __model
#• __year
#Provide
#• get_model()
#• set_model()
#• get_year()
#• set_year()
#Validation:
#Year cannot be greater than current year.

class Car:
    def __init__(self,model,year):
        self.__model = model
        self.__year = 0
        self.set__year = year
    def get_model(self):
        return self.__model
    def set_model(self,model):
        self.__model = model
    def get_year(self):
        return self.__year 
    def set_year(self,year):
        current_year = datetime.now().year
        if year <= current_year:
            self.__year = year
        else:
            print("invalid year")
c = Car("honda city",2004)
print(c.get_model())
print(c.get_year())
# Out:
# honda city
# 0

# %%
# question 8 Class Name: User
#Problem
#Create class User.
#Explanation
#Password must remain private.
#Private attribute
#__password
#Method
#change_password(new_password)
#Validation
#Password length ≥ 8

class User:
    def __init__(self,password):
        self.__password = ""
        self.change_password(password)
    def change_password(self,new_password):
        if len(new_password) >= 8:
            self.__password = new_password
            print("password changed successfully")
        else:
            print("password must be 8 charater long")
u = User("python123")
u.change_password("data123")
# Out:
# password changed successfully
# password must be 8 charater long

# %%
# question 9 Class Name: Rectangle
#Problem
#Create class Rectangle.
#Explanation
#Private attributes
#• __length
#• __width
#Methods
#• set_length()
#• get_length()
#• set_width()
#• get_width()
#• area()
#Validation
#Length and width must be positive.

class Rectangle:
    def __init__(self,length,width):
        self.__length = 0
        self.__width = 0
        self.set_length(length)
        self.set_width(width)
    def set_length(self,length):
        if length > 0:
            self.__length = length
        else:
            print("length should always be positive")
    def get_length(self):
        return self.__length
    def set_width(self,width):
        if width > 0:
            self.__width = width
        else:
            print("invalid width")
    def get_width(self):
        self.__width = width
    def area(self):
        return self.__length * self.__width
r = Rectangle(25,20)
print("area:",r.area())
# Out:
# area: 500

# %%
# question 10 Class Name: Account
#Problem
#Create class Account.
#Explanation
#Private attribute
#__balance
#Whenever balance changes,
#store every balance value inside a class variable
#Example
#history = []
#Methods
#• deposit()
#• withdraw()
#Every successful update should append the latest balance to history.

class Account:
    history =[]
    def __init__(self,balance):
        self.__balance = balance
        Account.history.append(self.__balance)
    def deposite(self,amount):
        if amount > 0:
            self.__balance += amount
            Account.history.append(self.__balance)
    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -= amount
            Account.history.append(self.__balance)
        else:
            print("insufficient balance")
    def get_balance(self):
        return self.__balance
a = Account(1000)
a.deposite(500)
a.withdraw(300)
print("balance:",a.get_balance())
print("history:",Account.history)
# Out:
# balance: 1200
# history: [1000, 1500, 1200]

# %%
# question 11 Class Name: Temperature
#Problem
#Create class Temperature.
#Explanation
#Store temperature privately.
#Private attribute
#__celsius
#Methods
#• set_celsius()
#• get_celsius()
#Also create
#• to_fahrenheit()
#Formula
#F = (C × 9/5) + 32

class Temperature:
    def __init__(self,celsius):
        self.__celsius = celsius
    def set_celsius(self):
        self.__celsius = celsius
    def get_celsius(self):
        return self.__celsius
    def to_farenheit(self):
        return (self.__celsius * 9/5)+ 32
t = Temperature(25)
print("celsius:",t.get_celsius())
print("farehneit:",t.to_farenheit())
# Out:
# celsius: 25
# farehneit: 77.0

# %%
# question 12 Class Name: Book
#Problem
#Create class Book.
#Explanation
#Private attribute
#__price
#Setter rule
#If price > 500
#automatically apply
#10% discount
#Store discounted price.
#Getter should return final stored price.

class Book:
    def __init__(self,price):
        self.__price = 0
        self.set_price(price)
    def set_price(self,price):
        if price > 500:
            self.__price = price*0.90
        else:
            self.__price = price
         
    def get_price(self):
        return self.__price
b = Book(500)
print("price:",b.get_price())
# Out:
# price: 500

# %%
# question 13 Class Name: Player
#Problem
#Create class Player.
#Explanation
#Private attribute
#__score
#Methods
#• set_score()
#• get_score()
#Validation
#Score cannot be negative.

class Player:
    def __init__(self,score):
        self.__score = 0
        self.set_score(score)
    def set_score(self,score):
        if score >= 0:
            self.__score = score
        else:
            print("score cannot be negative")
    def get_score(self):
        return self.__score
p = Player(90)
print("score:",p.get_score())
p.set_score(-10)
print("score:",p.get_score())
# Out:
# score: 90
# score cannot be negative
# score: 90

# %%
# question 14 Class Name: Laptop
#Problem
#Create class Laptop.
#Explanation
#Private attributes
#• __ram
#• __storage
#Provide
#• getter
#• setter
#Validation
#RAM and Storage should always be positive.

class Laptop:
    def __init__(self,ram,storage):
        self.__ram = 0
        self.__storage = 0
        self.set_ram(ram)
        self.set_storage(storage)
    def set_ram(self,ram):
        if ram>0:
            self.__ram = ram
        else:
            print("RAM should be positive")
    def get_ram(self):
        return self.__ram
    def set_storage(self,storage):
        if storage > 0:
            self.__storage = storage
        else:
            print("storage should be positive")
    def get_storage(self):
        return self.__storage
l = Laptop(8,512)
print("ram:",l.get_ram())
print("storage:",l.get_storage())
# Out:
# ram: 8
# storage: 512

# %%
# question 15 Class Name: Employee
#Problem
#Create class Employee.
#Explanation
#Private attributes
#• __id
#• __salary
#Create getter methods.
#Finally,
#outside the class,
#try
#employee.__salary
#Observe the error.
#Then access using
#name mangling
#to understand how Python stores private attributes.

class Employee:
    def __init__(self,emp_id,salary):
        self.__id = emp_id
        self.__salary = salary
    def get_id(self):
        return self.__id
    def get_salary(self):
        return self.__salary
employee = Employee(101,50000)
print("ID:",employee.get_id())
print("salary:",employee.get_salary())
try:
    print(employee.__salary)
except AttributeError as e:
    print("error:", e)
print("using name mangling:",employee._Employee__salary)
# Out:
# ID: 101
# salary: 50000
# error: 'Employee' object has no attribute '__salary'
# using name mangling: 50000

# %% [markdown]
# ### Abstraction Practice Questions (16–30)

# %%
# question 16 Class Name: Shape
#Problem
#Create an abstract class Shape.
#Explanation
#Declare abstract methods
#• calculate_area()
#• calculate_perimeter()
#Create subclasses like
#• Circle
#• Rectangle
#Implement both methods.

from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass
    @abstractmethod
    def calculate_perimeter(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius 
    def calculate_area(self):
        return 3.14 *self.radius * self.radius
    def calculate_perimeter(self):
        return 2 * 3.14 * self.radius
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width = width
    def calculate_area(self):
        return self.length * self.width
    def calculate_perimeter(self):
        return 2 *(self.length + self.width)
c = Circle(7)
print("Circle Area:",c.calculate_area())
print("Circle perimeter:",c.calculate_perimeter())
r = Rectangle(10,5)
print("Rectangle Area:",r.calculate_area())
print("Rectangle Perimeter:",r.calculate_perimeter())
# Out:
# Circle Area: 153.86
# Circle perimeter: 43.96
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %%
# question 17 Class Name: Vehicle
#Problem
#Create abstract class Vehicle.
#Explanation
#Abstract methods
#• start()
#• stop()
#Implement in
#• Car
#• Bike
#Each subclass should define how the vehicle starts and stops.

from abc import ABC, abstractmethod
class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def stop(self):
        pass
class Car(Vehicle):
    def start(self):
        print("Car started")
    def stop(self):
        print("Car Stopped")
class Bike(Vehicle):
    def start(self):
        print("Bike started")
    def stop(self):
        print("Bike Stopped")
c = Car()
c.start()
c.stop()
b = Bike()
b.start()
b.stop()
# Out:
# Car started
# Car Stopped
# Bike started
# Bike Stopped

# %%
# question 18 Class Name: Payment
#Problem
#Create abstract class Payment.
#Explanation
#Abstract method
#process_payment(amount)
#Create subclasses
#• CreditCardPayment
#• UPIPayment
#Each should process payment differently.

from abc import ABC, abstractmethod
class Payment(ABC):
    @abstractmethod
    def process_payment(self,amount):
        pass
class CreditCardPayment(Payment):
    def process_payment(self,amount):
        print(f"credit card payment of {amount} processed successfully")
class UPIPayment(Payment):
    def process_payment(self,amount):
        print(f"UPI payment of {amount} processed successfully")
cc = CreditCardPayment()
upi = UPIPayment()
cc.process_payment(5000)
upi.process_payment(2500)
# Out:
# credit card payment of 5000 processed successfully
# UPI payment of 2500 processed successfully

# %%
# question 19 Class Name: Animal
#Problem
#Create abstract class Animal.
#Explanation
#Abstract method
#make_sound()
#Create subclasses
#• Dog
#• Cat
#Each returns its own sound.

from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass
class Dog(Animal):
    def make_sound(self):
        print("Dog says: woof woof!")
class Cat(Animal):
    def make_sound(self):
        print("cat says: meow meow!")
dog = Dog()
cat = Cat()
dog.make_sound()
cat.make_sound()
# Out:
# Dog says: woof woof!
# cat says: meow meow!

# %%
# question 20 Class Name: Report
#Problem
#Create abstract class Report.
#Explanation
#Abstract method
#generate_report()
#Create
#• PDFReport
#• ExcelReport
#Each generates report differently.

from abc import ABC,abstractmethod
class Report(ABC):
    @abstractmethod
    def generate_report(self):
        pass
class PDFReport(Report):
    def generate_report(self):
        print("Generating PDF report")
class ExcelReport(Report):
    def generate_report(self):
        print("Generating Excel report")
pdf = PDFReport()
excel = ExcelReport()
pdf.generate_report()
excel.generate_report()
# Out:
# Generating PDF report
# Generating Excel report

# %%
# question 21 Class Name: BankAccount
#Problem
#Create abstract class BankAccount.
#Explanation
#Abstract method
#calculate_interest()
#Implement in
#• SavingsAccount
#• CurrentAccount
#Each account type should use a different interest calculation.

from abc import ABC,abstractmethod
class BankAccount(ABC):
    @abstractmethod
    def calculate_interest(self):
        pass
class SavingsAccount(BankAccount):
    def calculate_interest(self):
        print("calculate saving account interest")
class CurrentAccount(BankAccount):
    def calculate_interest(self):
        print("calculate current account interest")
saving = SavingsAccount()
current = CurrentAccount()
saving.calculate_interest()
current.calculate_interest()
# Out:
# calculate saving account interest
# calculate current account interest

# %%
# question 22 Class Name: Device
#Problem
#Create abstract class Device.
#Explanation
#Abstract methods
#• turn_on()
#• turn_off()
#Implement in
#• TV
#• Laptop
#• Fan
#Each device should define its own behavior.

from abc import ABC, abstractmethod
class Device(ABC):
    @abstractmethod
    def turn_on(self):
        pass 
    @abstractmethod
    def turn_off(self):
        pass
class TV(Device):
    def turn_on(self):
        print("TV is trun on")
    def turn_off(self):
        print("TV is turn off")
class Laptop(Device):
    def turn_on(self):
        print("laptop is turn on")
    def turn_off(self):
        print("laptop is turn off")
class Fan(Device):
    def turn_on(self):
        print("fan is turn on")
    def turn_off(self):
        print("fan is turn off")
tv= TV()
laptop = Laptop()
fan = Fan()
tv.turn_on()
tv.turn_off()
laptop.turn_on()
laptop.turn_off()
fan.turn_on()
fan.turn_off()
# Out:
# TV is trun on
# TV is turn off
# laptop is turn on
# laptop is turn off
# fan is turn on
# fan is turn off

# %%
# question 23 Class Name: Calculator
#Problem
#Create abstract class Calculator.
#Explanation
#Abstract method
#compute(a, b)
#Implement in
#• AddCalculator
#• MultiplyCalculator
#Each subclass performs a different operation.

from abc import ABC, abstractmethod
class Calculator(ABC):
    @abstractmethod
    def compute(self,a,b):
        pass
class AddCalculator(Calculator):
    def compute(self,a,b):
        return a + b 
class MultiplyCalculator(Calculator):
    def compute(self,a,b):
        return a * b
add = AddCalculator()
print("Addition:",add.compute(10,5))
multiply = MultiplyCalculator()
print("Multiplication:",multiply.compute(3,2))
# Out:
# Addition: 15
# Multiplication: 6

# %%
# question 24 Class Name: Employee
#Problem
#Create abstract class Employee.
#Explanation
#Abstract method
#calculate_bonus()
#Create subclasses
#• Manager
#• Developer
#• HR
#Each has its own bonus calculation rule.

from abc import ABC, abstractmethod
class Employee(ABC):
    @abstractmethod
    def calculate_bonus(self):
        pass
class Manager(Employee):
    def __init__(self,salary):
        self.salary = salary
    def calculate_bonus(self):
        return self.salary * 0.20
class Developer(Employee):
    def __init__(self,salary):
        self.salary = salary
    def calculate_bonus(self):
        return self.salary * 0.15
class HR(Employee):
    def __init__(self,salary):
        self.salary = salary
    def calculate_bonus(self):
        return self.salary * 0.10
man = Manager(40000)
dev = Developer(40000)
hr = HR(40000)
print("salary:",man.calculate_bonus())
print("salary:",dev.calculate_bonus())
print("salary:",hr.calculate_bonus())
# Out:
# salary: 8000.0
# salary: 6000.0
# salary: 4000.0

# %%
# question 25 Class Name: Shape3D
#Problem
#Create abstract class Shape3D.
#Explanation
#Abstract methods
#• volume()
#• surface_area()
#Implement in
#• Cube
#• Sphere
#• Cylinder
#Each uses different formulas.

from abc import ABC,abstractmethod
import math
class Shape3D:
    @abstractmethod
    def volume(self):
        pass
    @abstractmethod
    def surface_area(self):
        pass
class Cube(Shape3D):
    def __init__(self,side):
        self.side  = side
    def volume(self):
        return self.side ** 3
    def surface_area(self):
        return 6 * self.side ** 2
class Sphere(Shape3D):
    def __init__(self,radius):
        self.radius = radius
    def volume(self):
        return (4/3) * math.pi * self.radius ** 3
    def surface_area(self):
        return 4 * math.pi * self.radius ** 2
class Cylinder(Shape3D):
    def __init__(self,radius,height):
        self.radius = radius
        self.height = height
    def volume(self):
        return math.pi * self.radius ** 2 * self.height
    def surface_area(self):
        return 2 * math.pi * self.radius * (self.radius + self.height)
cube = Cube(4)
print("cube volume:",cube.volume())
print("cube surface_area:",cube.surface_area())
sphere = Sphere(3)
print("sphere volume:",sphere.volume())
print("sphere surface_area:",sphere.surface_area())
cylinder = Cylinder(3,4)
print("cylinder volume:", cylinder.volume())
print("cylinder surface_area:", cylinder.surface_area())
# Out:
# cube volume: 64
# cube surface_area: 96
# sphere volume: 113.09733552923254
# sphere surface_area: 113.09733552923255
# cylinder volume: 113.09733552923255
# cylinder surface_area: 131.94689145077132

# %%
# question 26 Class Name: Notification
#Problem
#Create abstract class Notification.
#Explanation
#Abstract method
#send(message)
#Implement
#• EmailNotification
#• SMSNotification
#Each sends the message in its own way.

from abc import ABC, abstractmethod
class Notification(ABC):
    @abstractmethod
    def send(self,message):
        pass
class EmailNotification(Notification):
    def send(self,message):
        print("email sent:",message)
class SMSNotification(Notification):
    def send(self,message):
        print("email sent:",message)
email = EmailNotification()
email.send("welcome to python!")
sms = SMSNotification()
sms.send("your OTP is 123456")
# Out:
# email sent: welcome to python!
# email sent: your OTP is 123456

# %%
# question 27 Class Name: Database
#Problem
#Create abstract class Database.
#Explanation
#Abstract methods
#• connect()
#• query(sql)
#Implement in
#• MySQLDatabase
#• MongoDatabase
#Each should define how it connects and executes queries.

from abc import ABC,abstractmethod
class Database(ABC):
    @abstractmethod
    def connect(self):
        pass
    @abstractmethod
    def query(self,sql):
        pass
class MySQLDatabase(Database):
    def connect(self):
        print("connected to mysql databse")
    def query(self,sql):
        print("executing my sql query:",sql)
class MongoDatabase(Database):
    def connect(self):
        print("connected to mongoDB")
    def query(self,sql):
        print("executing mongoDB query:",sql)
sql = MySQLDatabase()
sql.connect()
sql.query("SELECT * from users")
mongo = MongoDatabase()
mongo.connect()
mongo.query("{find: 'users'}")
# Out:
# connected to mysql databse
# executing my sql query: SELECT * from users
# connected to mongoDB
# executing mongoDB query: {find: 'users'}

# %%
# question 28 Class Name: GameCharacter
#Problem
#Create abstract class GameCharacter.
#Explanation
#Abstract method
#attack()
#Implement in
#• Warrior
#• Archer
#• Mage
#Each character attacks differently.

from abc import ABC,abstractmethod
class GameCharacter(ABC):
    @abstractmethod
    def attack(self):
        pass
class Warrior(GameCharacter):
    def attack(self):
        print("warrior attacks on a sword!")
class Archer(GameCharacter):
    def attack(self):
        print("Archer attacks with bow and arrow!")
class Mage(GameCharacter):
    def attack(self):
        print("mage attack with magic spell!")
war = Warrior()
arc = Archer()
mag = Mage()
war.attack()
arc.attack()
mag.attack()
# Out:
# warrior attacks on a sword!
# Archer attacks with bow and arrow!
# mage attack with magic spell!

# %%
# question 29 Class Name: Transport
#Problem
#Create abstract class Transport.
#Explanation
#Abstract methods
#• move()
#• fuel_type()
#Implement in
#• Car
#• Train
#• Airplane
#Each should define:
#• how it moves
#• what fuel or power source it uses (e.g., Petrol, Diesel, Electricity, Aviation Fuel).

from abc import ABC,abstractmethod
class Transport(ABC):
    @abstractmethod
    def move(self):
        pass
    def fuel_type(self):
        pass
class Car(Transport):
    def move(self):
        print("car moves on road!")
    def fuel_type(self):
        print("Fuel: petrol")
class Train(Transport):
    def move(self):
        print("Train moves on railway track !")
    def fuel_type(self):
        print("Fuel: Electricity")
class Airplane(Transport):
    def move(self):
        print("Airplane files in the sky")
    def fule_type(self):
        print("Fuel: Aviation fuel")
c = Car()
c.move()
c.fuel_type()
t =Train()
t.move()
t.fuel_type()
a = Airplane()
a.move()
a.fuel_type()
# Out:
# car moves on road!
# Fuel: petrol
# Train moves on railway track !
# Fuel: Electricity
# Airplane files in the sky

# %%
# question 30 Class Name: FileHandler
#Problem
#Create abstract class FileHandler.
#Explanation
#Abstract methods
#• read()
#• write(data)
#Implement in
#• TextFileHandler
#• CSVFileHandler
#Each subclass should define how it reads from and writes to its respective file type.

from abc import ABC, abstractmethod
class FileHandler(ABC):
    @abstractmethod
    def read(self):
        pass
    def write(self,data):
        pass
class TextFileHandler(FileHandler):
    def read(self):
        print("reading data from text file")
    def write(self,data):
        print("writing to text file:", data)
class CSVFileHandler(FileHandler):
    def read(self):
        print("reading data from csv file ")
    def write(self,data):
        print("writing to csv file:",data)
text = TextFileHandler()
text.read()
text.write("hello python")
csv = CSVFileHandler()
csv.read()
csv.write("name,age")
# Out:
# reading data from text file
# writing to text file: hello python
# reading data from csv file
# writing to csv file: name,age
