# %% [markdown]
# ## Logical operator (and, or, not)

# %%
# question 1
age = int(input("Enter age: "))
marks = int(input("Enter marks: "))
eligible = (age >= 18 and age <= 25) and (marks >= 60)
Not_eligible = (age != 25)
print(eligible)
# Out:
# Enter age:  34
# Enter marks:  60
# False

# %%
# question 2
username = input("Enter username: ")
password = input("Enter password: ")
print(username == "admin" and password =="12345")
# Out:
# Enter username:  dilnaz pathan
# Enter password:  5678
# False

# %%
# question 3
num = int (input("Enter number: "))
divisible = (num >= 50 and num <= 100) and not (num % 5 == 0)
Not_divisible = (num % 5 == 0)
print(divisible)
# Out:
# Enter number:  45
# False

# %%
# question 4
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter second number: "))
print(num1 > num2)
print(num1 > num3)
print(num2 > num3)
# Out:
# Enter first number:  45
# Enter second number:  78
# Enter second number:  89
# False
# False
# False

# %% [markdown]
# ### String and string slicing

# %%
# question 1
name = input("Enter your full name: ")
print("Uppercase: ", name.upper())
# Out:
# Enter your full name:  dilnaz pathan
# Uppercase:  DILNAZ PATHAN

# %%
print("Lowercase: ", name.lower())
# Out:
# Lowercase:  dilnaz pathan

# %%
name = input("Enter your full name: ")
print("length: ",len(name))
# Out:
# Enter your full name:  Dilnaz pathan
# length:  13

# %%
lis="Dilnaz"
lis=lis[ :3]
print(lis)
# Out:
# Dil

# %%
lis="Dilnaz"
lis=lis[-3: ]
print(lis)
# Out:
# naz

# %%
# question 2
str = input("Enter any sentence: ")
name = str [ :10]
print(name)
# Out:
# Enter any sentence:  hello welcome to python
# hello welc

# %%
name = str [10: ]
print(name)
# Out:
# ome to python

# %%
name = str[5:15]
print(name)
# Out:
#  welcome t

# %%
name = str [::2]
print(name)
# Out:
# hlowloet yhn

# %%
# question 3
word = input("Write any word: ")
if word == word[::-1]:
    print("palindrome")
else:
    print("Not a palindrome")
# Out:
# Write any word:  madam
# palindrome

# %%
# question 4
email = input("Write your email:")
pos = email.find("@")
print("username:" ,email[:pos])
# Out:
# Write your email: dilnaz@gmail.com
# username: dilnaz

# %%
print("domain:", email[pos:])
# Out:
# domain: @gmail.com

# %% [markdown]
# ### Bonus mixed question

# %%
# question 1
password = input("Enter your password:")
if len(password) >= 8 and ("@" in password or "#" in password):
    print("Strong password")
else:
    print("Weak password")
# Out:
# Enter your password: sdfew
# Weak password

# %%
#logical operator
English = int(input("Enter English marks:"))
Math= int(input("Enter Math marks:"))
Science= int(input("Enter Science marks:"))
if English >= 40 and Math >= 40 and Science >= 40 :
    print("Pass")
else:
    print("Fail")
# Out:
# Enter English marks: 78
# Enter Math marks: 76
# Enter Science marks: 89
# Pass

# %%
# Logical operator + user input
num = int(input("Enter number:"))
if num > 0 and num % 2 == 0:
    print("Positive and Even")
else:
    print("Negative or Odd")
# Out:
# Enter number: 56
# Positive and Even

# %%
# String operations
city = input("Enter your city:")
print("Reverse: ",city[::-1])
vowels="aeiou"
count = 0
for ch in city:
   if ch in vowels:
    count += 1

print("number of vowels:", count)
print("without first and last charecter:",city[1:-1])
# Out:
# Enter your city: hyderabad
# Reverse:  dabaredyh
# number of vowels: 3
# without first and last charecter: yderaba

# %%
# String Slicing
num = input("Enter your 10 digit mobile no.:")
num = num[ :3]
print(num)
# Out:
# Enter your 10 digit mobile no.: 7473636252
# 747

# %%
num = input("Enter your 10 digit mobile no.:")
num = num[-4: ]
print(num)
# Out:
# Enter your 10 digit mobile no.: 866785658
# 5658

# %%
num = input("Enter your 10 digit mobile no.:")
num = num[3:6]
print(num)
# Out:
# Enter your 10 digit mobile no.: 7689543298
# 954

# %%
# Mixed (string + logical)
text= input("Enter string:")
if len(text) > 5 and (text[0] == 'A' or text[0] == 'a'):
    print("Valid string")
else:
    print("Invalid string")
# Out:
# Enter string: adamapple
# Valid string
